# %% [markdown]
# ## Twitter Sentiment Analysis (Text Classification Problem)

# %%
#Importing all Libraries

# %%
import nltk

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv( 'training.1600000.processed.noemoticon.csv',
                 delimiter=',', encoding='ISO-8859-1')
df
# Out:
#          polarity of tweet   id of the tweet             date of the tweet  \
# 0                         0       1467810672  Mon Apr 06 22:19:49 PDT 2009
# 1                         0       1467810917  Mon Apr 06 22:19:53 PDT 2009
# 2                         0       1467811184  Mon Apr 06 22:19:57 PDT 2009
# 3                         0       1467811193  Mon Apr 06 22:19:57 PDT 2009
# 4                         0       1467811372  Mon Apr 06 22:20:00 PDT 2009
# ...                     ...              ...                           ...
# 1048567                   4       1960186342  Fri May 29 07:33:44 PDT 2009
# 1048568                   4       1960186409  Fri May 29 07:33:43 PDT 2009
# 1048569                   4       1960186429  Fri May 29 07:33:44 PDT 2009
# 1048570                   4       1960186445  Fri May 29 07:33:44 PDT 2009
# 1048571                   4       1960186607  Fri May 29 07:33:45 PDT 2009
#
#             query             user  \
# 0        NO_QUERY    scotthamilton
# 1        NO_QUERY         mattycus
# 2        NO_QUERY          ElleCTF
# 3        NO_QUERY           Karoli
# 4        NO_QUERY         joy_wolf
# ...           ...              ...
# 1048567  NO_QUERY  Madelinedugganx
# 1048568  NO_QUERY     OffRoad_Dude
# 1048569  NO_QUERY         Falchion
# 1048570  NO_QUERY   jonasobsessedx
# 1048571  NO_QUERY        sugababez
#
#                                         text of the tweet
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1048567           My GrandMa is making Dinenr with my Mum
# 1048568  Mid-morning snack time... A bowl of cheese noo...
# 1048569  @ShaDeLa same here  say it like from the Termi...
# 1048570             @DestinyHope92 im great thaanks  wbuu?
# 1048571               cant wait til her date this weekend
#
# [1048572 rows x 6 columns]

# %%
df.columns = ['Sentiment','id','date','query','user','text']
df.head()
# Out:
#    Sentiment          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
#
#             user                                               text
# 0  scotthamilton  is upset that he can't update his Facebook by ...
# 1       mattycus  @Kenichan I dived many times for the ball. Man...
# 2        ElleCTF    my whole body feels itchy and like its on fire
# 3         Karoli  @nationwideclass no, it's not behaving at all....
# 4       joy_wolf                      @Kwesidei not the whole crew

# %%
df = df[['Sentiment','text']]

# %%
df.columns
# Out:
# Index(['Sentiment', 'text'], dtype='object')

# %%
#printing the sentiment value count

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 4    248576
# Name: count, dtype: int64

# %%
df['Sentiment'] = df['Sentiment'].replace({4:1})
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# * 0 represent Negative sentiment
# * 1 represents Positive sentiment

# %%
#checking for null values

# %%
df.isna().sum()
# Out:
# Sentiment    0
# text         0
# dtype: int64

# %% [markdown]
# **Inference: The data is unbalanced therefore we will downsample the data to have same count for each sentiment**

# %% [markdown]
# *italicized text*## Downsampling the dataset

# %%
from sklearn.utils import resample

# %%
## majority class 0
df_majority = df[df['Sentiment']==0]
## minority class 1
df_minority = df[df['Sentiment']==1]

# %%
#printing the minority of the sentiment

# %%
df_minority.shape
# Out:
# (248576, 2)

# %%
##printing the majority of the sentiment

# %%
df_majority.shape
# Out:
# (799996, 2)

# %%
# downsample the majority class
df_majority_downsampled = resample(df_majority,
                                 replace=False,
                                 n_samples=len(df_minority),
                                 random_state=1234)

# %%
df_majority_downsampled.count
# Out:
# <bound method DataFrame.count of         Sentiment                                               text
# 74567           0  Wow slept for almost 12hours. Sleepy me!! Uni ...
# 668722          0  gets bored with an idea too easily ... like tw...
# 286706          0  To my girls - sorry i've been a homebody latel...
# 632911          0  BK once again for the weekend...If it wasnt fo...
# 356735          0  @DonnieWahlberg Now why didn't you do that las...
# ...           ...                                                ...
# 341825          0  I am so sleepy this morning.  It's so hard to ...
# 727291          0  @mEgG_eLizAbEtH episode 10 isn't on the websit...
# 394909          0  @TeeAngie LOL @ asking that. Womp Womp LOL @mi...
# 210057          0  never had me medicin so now i have to wait an ...
# 463307          0  @aarondelgado The fake cheese  Yuck ! Now the ...
#
# [248576 rows x 2 columns]>

# %%
frames = [df_majority_downsampled, df_minority]

df = pd.concat(frames)
df.head()
# Out:
#         Sentiment                                               text
# 74567           0  Wow slept for almost 12hours. Sleepy me!! Uni ...
# 668722          0  gets bored with an idea too easily ... like tw...
# 286706          0  To my girls - sorry i've been a homebody latel...
# 632911          0  BK once again for the weekend...If it wasnt fo...
# 356735          0  @DonnieWahlberg Now why didn't you do that las...

# %%
#printing the balanced sentiment for Negative==0 & Positive==1

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# [link text](https://)## Data Preprocessing
#
# 1. removing stop words
# 2. removing punctuations
# 3. Stemmer
# 4. removing tags
# 5. removing special characters
# 6. lowercase conversion

# %%
## remove stopwords and punctuation marks
nltk.download('stopwords')
stuff_to_be_removed = list(stopwords.words('english'))+list(punctuation)
stemmer = LancasterStemmer()

corpus = df['text'].tolist()
print(len(corpus))
print(corpus[0])
# Out:
# 497152
# Wow slept for almost 12hours. Sleepy me!! Uni now, boo! I wanna stay home, drink tea and watch house...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('wordnet')
# %%time
final_corpus = []
final_corpus_joined = []
for i in df.index:

    text = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    #Convert to lowercase
    text = text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)

    ##Convert to list from string
    text = text.split()

    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text
            if not word in stuff_to_be_removed]
    text1 = " ".join(text)
    final_corpus.append(text)
    final_corpus_joined.append(text1)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #### Storing the cleaned data seperately

# %%
data_cleaned = pd.DataFrame()
data_cleaned["text"] = final_corpus_joined
data_cleaned["Sentiment"] = df["Sentiment"].values

# %%
data_cleaned['Sentiment'].value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %%
data_cleaned.head()
# Out:
#                                                 text  Sentiment
# 0  wow slept almost hour sleepy uni boo wanna sta...          0
# 1                 get bored idea easily like twitter          0
# 2  girl sorry homebody lately dont feel well does...          0
# 3                     bk weekend wasnt puppy stay as          0
# 4                  donniewahlberg last night atlanta          0

# %%
data_cleaned.tail()
# Out:
#                                                      text  Sentiment
# 497147                          grandma making dinenr mum          1
# 497148      mid morning snack time bowl cheese noodle yum          1
# 497149  shadela say like terminiator movie come like word          1
# 497150                  destinyhope im great thaanks wbuu          1
# 497151                         cant wait til date weekend          1

# %% [markdown]
# ## EDA

# %%
data_eda = pd.DataFrame()
data_eda['text'] = final_corpus
data_eda['Sentiment'] = df["Sentiment"].values
data_eda.head()
# Out:
#                                                 text  Sentiment
# 0  [wow, slept, almost, hour, sleepy, uni, boo, w...          0
# 1          [get, bored, idea, easily, like, twitter]          0
# 2  [girl, sorry, homebody, lately, dont, feel, we...          0
# 3              [bk, weekend, wasnt, puppy, stay, as]          0
# 4             [donniewahlberg, last, night, atlanta]          0

# %%
# Storing positive data seperately
positive = data_eda[data_eda['Sentiment'] == 1]
positive_list = positive['text'].tolist()

# Storing negative data seperately

negative = data_eda[data_eda['Sentiment'] == 0]
negative_list = negative['text'].tolist()

####TO BE USE FOR TESTING AND TRAINNING THE MODEL

# %%
positive_all = " ".join([word for sent in positive_list for word in sent ])
negative_all = " ".join([word for sent in negative_list for word in sent ])

# %% [markdown]
# #### Word Cloud Positive data

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(positive_all)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.title("Positive Word Cloud")
plt.show()

# %% [markdown]
# #### Word CLoud Negative data

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(negative_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.title("Negative Word Cloud")
plt.show()

# %% [markdown]
# **Inference:**
# * Positive data has words like Thank, love , LOL, Haha ets
# * Negative data has words like work, sad, tired, suck sorry <br>
# Some of the words are still common in both such as Lol, quot

# %% [markdown]
# #### One word count

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    return(dic)
count_corpus = get_count(positive_list)

# %%
count_corpus
# Out:
# {'love': 14969,
#  'health': 139,
#  'uandpets': 6,
#  'u': 12448,
#  'guy': 3475,
#  'r': 1829,
#  'best': 3431,
#  'im': 6434,
#  'meeting': 662,
#  'one': 8907,
#  'besties': 40,
#  'tonight': 3642,
#  'cant': 1515,
#  'wait': 4036,
#  'girl': 2891,
#  'talk': 1287,
#  'darealsunisakim': 3,
#  'thanks': 11375,
#  'twitter': 7193,
#  'add': 770,
#  'sunisa': 1,
#  'got': 8267,
#  'meet': 1108,
#  'hin': 5,
#  'show': 2898,
#  'dc': 143,
#  'area': 193,
#  'sweetheart': 105,
#  'sick': 486,
#  'really': 5887,
#  'cheap': 146,
#  'hurt': 370,
#  'much': 5265,
#  'eat': 1078,
#  'real': 1229,
#  'food': 1170,
#  'plus': 392,
#  'friend': 4308,
#  'make': 5340,
#  'soup': 177,
#  'lovesbrooklyn': 2,
#  'effect': 131,
#  'everyone': 3105,
#  'productoffear': 1,
#  'tell': 1916,
#  'burst': 24,
#  'laughing': 254,
#  'loud': 172,
#  'making': 1353,
#  'come': 4094,
#  'sulk': 5,
#  'keith': 40,
#  'hill': 279,
#  'thans': 1,
#  'response': 141,
#  'ihad': 3,
#  'already': 1667,
#  'find': 1614,
#  'answer': 402,
#  'keepinupwkris': 14,
#  'jealous': 354,
#  'hope': 6486,
#  'great': 8328,
#  'time': 10718,
#  'vega': 303,
#  'like': 12013,
#  'acm': 3,
#  'tommcfly': 570,
#  'ah': 976,
#  'congrats': 967,
#  'mr': 704,
#  'fletcher': 18,
#  'finally': 2434,
#  'joining': 105,
#  'e': 1137,
#  'voip': 7,
#  'responded': 30,
#  'stupid': 354,
#  'cat': 553,
#  'helping': 233,
#  'type': 285,
#  'forgive': 60,
#  'error': 62,
#  'crazy': 909,
#  'day': 19789,
#  'school': 2639,
#  'hour': 2500,
#  'straiiight': 1,
#  'watch': 2565,
#  'spencerpratt': 38,
#  'told': 585,
#  'ha': 1457,
#  'happy': 8155,
#  'birthday': 2343,
#  'jb': 137,
#  'naughtyhaughty': 3,
#  'forget': 548,
#  'two': 1540,
#  'half': 768,
#  'men': 372,
#  'nileyjileyluver': 1,
#  'haha': 6390,
#  'worry': 793,
#  'get': 11490,
#  'hang': 496,
#  'soundwav': 1,
#  'least': 1241,
#  'feeling': 1439,
#  'lost': 678,
#  'may': 1777,
#  'cause': 737,
#  'many': 1276,
#  'later': 2009,
#  'usual': 266,
#  'night': 8043,
#  'addicting': 59,
#  'lutheranlucciol': 1,
#  'sure': 2907,
#  'dm': 430,
#  'post': 1338,
#  'link': 922,
#  'video': 1692,
#  'lt': 3335,
#  'lol': 10741,
#  'gt': 1110,
#  'miss': 1835,
#  'better': 3898,
#  'permission': 21,
#  'blessing': 144,
#  'first': 3004,
#  'added': 319,
#  'tweetie': 194,
#  'new': 7882,
#  'iphone': 619,
#  'michellardi': 1,
#  'know': 8450,
#  'think': 6485,
#  'globe': 28,
#  'yeah': 3888,
#  'sana': 17,
#  'gumaling': 1,
#  'na': 318,
#  'ko': 103,
#  'para': 27,
#  'alam': 6,
#  'din': 85,
#  'kung': 24,
#  'makakasama': 1,
#  'ako': 56,
#  'nicolerichie': 67,
#  'picture': 1318,
#  'sweet': 1882,
#  'catching': 223,
#  'email': 790,
#  'rss': 45,
#  'random': 405,
#  'bacn': 2,
#  'cutting': 61,
#  'early': 1480,
#  'pm': 759,
#  'dinner': 1275,
#  'lauraw': 1,
#  'dancing': 321,
#  'around': 1515,
#  'room': 868,
#  'pjs': 28,
#  'jamming': 35,
#  'ipod': 413,
#  'getting': 3385,
#  'dizzy': 13,
#  'well': 7521,
#  'asked': 310,
#  'place': 1170,
#  'peep': 317,
#  'contest': 178,
#  'voting': 86,
#  'anyways': 240,
#  'going': 9424,
#  'bed': 3518,
#  'goodnight': 1521,
#  'dream': 1182,
#  'http': 14800,
#  'twitpic': 4101,
#  'com': 11017,
#  'littlelumen': 2,
#  'walking': 296,
#  'put': 1346,
#  'deposit': 10,
#  'tomorrow': 4485,
#  'followinq': 1,
#  'dachesterfrench': 3,
#  'shud': 55,
#  'tha': 172,
#  'lordpov': 1,
#  'meant': 393,
#  'back': 7359,
#  'quot': 14567,
#  'twittering': 322,
#  'toilet': 56,
#  'cubicle': 13,
#  'somewhere': 244,
#  'aw': 431,
#  'holding': 99,
#  'puppy': 227,
#  'mine': 1043,
#  'cutie': 94,
#  'ijohn': 1,
#  'kitteh': 10,
#  'sleepin': 28,
#  'crotch': 4,
#  'prof': 36,
#  'dramabeats': 9,
#  'agreed': 144,
#  'reaching': 28,
#  'amritsar': 1,
#  'bus': 366,
#  'wagah': 1,
#  'border': 34,
#  'bkite': 33,
#  'fuj': 1,
#  'albinla': 1,
#  'thinking': 1155,
#  'let': 3199,
#  'interview': 417,
#  'famous': 206,
#  'super': 871,
#  'star': 1143,
#  'spend': 362,
#  'family': 1319,
#  'tired': 1401,
#  'gonna': 3149,
#  'didnt': 507,
#  'effing': 89,
#  'throat': 80,
#  'hurting': 37,
#  'ooooohh': 2,
#  'craving': 108,
#  'pina': 14,
#  'colada': 5,
#  'banana': 158,
#  'slushie': 2,
#  'deon': 14,
#  'upload': 189,
#  'di': 103,
#  'indowebster': 1,
#  'dong': 36,
#  'banggggg': 1,
#  'wisdomous': 1,
#  'welcome': 2327,
#  'glad': 2655,
#  'enjoyed': 517,
#  'hawaii': 74,
#  'shellz': 2,
#  'hahaha': 1440,
#  'omg': 1313,
#  'wer': 12,
#  'laughin': 9,
#  'hook': 92,
#  'cuz': 469,
#  'da': 507,
#  'rolll': 1,
#  'ryt': 13,
#  'sheldawg': 1,
#  'sickwiththepen': 2,
#  'awww': 634,
#  'pookie': 7,
#  'feel': 3142,
#  'pray': 213,
#  'bag': 306,
#  'nurse': 44,
#  'yay': 3130,
#  'found': 1266,
#  'cuddle': 78,
#  'buddy': 312,
#  'met': 439,
#  'snob': 13,
#  'bad': 1800,
#  'life': 2804,
#  'go': 9170,
#  'across': 162,
#  'universe': 78,
#  'sleep': 3374,
#  'rehearsal': 83,
#  'annabellee': 1,
#  'dry': 114,
#  'potato': 108,
#  'huh': 339,
#  'jonathanrknight': 282,
#  'hi': 2402,
#  'jon': 179,
#  'hear': 1451,
#  'see': 7948,
#  'cruise': 133,
#  'cannot': 251,
#  'knight': 126,
#  'loved': 957,
#  'long': 2563,
#  'conversation': 198,
#  'mom': 2244,
#  'phone': 1295,
#  'suitelifeofkell': 6,
#  'yayyy': 96,
#  'requested': 17,
#  'herrr': 5,
#  'say': 3846,
#  'practicing': 42,
#  'line': 481,
#  'mannerism': 1,
#  'voice': 423,
#  'upcoming': 68,
#  'feature': 161,
#  'shoot': 328,
#  'probably': 928,
#  'driving': 379,
#  'brock': 6,
#  'read': 1581,
#  'moon': 257,
#  'rd': 262,
#  'enough': 958,
#  'twilight': 360,
#  'series': 268,
#  'today': 9627,
#  'month': 944,
#  'anniversary': 166,
#  'sooooooo': 38,
#  'diana': 53,
#  'dont': 1694,
#  'even': 2145,
#  'tar': 11,
#  'heel': 67,
#  'ncaa': 7,
#  'woot': 373,
#  'bored': 734,
#  'stevecla': 3,
#  'wallpaper': 55,
#  'red': 652,
#  'square': 74,
#  'asking': 296,
#  'pope': 14,
#  'mello': 3,
#  'noticed': 161,
#  'bb': 167,
#  'tryna': 51,
#  'inspired': 138,
#  'thats': 1604,
#  'kourtneykardash': 29,
#  'workout': 203,
#  'ladygaga': 39,
#  'ur': 2496,
#  'hot': 1400,
#  'as': 578,
#  'austin': 98,
#  'annnd': 10,
#  'bob': 125,
#  'purple': 145,
#  'went': 1680,
#  'royal': 50,
#  'color': 239,
#  'way': 4106,
#  'quotablebuffy': 4,
#  'bunch': 234,
#  'buffy': 34,
#  'song': 3005,
#  'faves': 52,
#  'vivian': 3,
#  'nerf': 4,
#  'herder': 2,
#  'faith': 127,
#  'spike': 29,
#  'body': 294,
#  'devunity': 1,
#  'check': 2009,
#  'morning': 7738,
#  'tweetland': 5,
#  'ahead': 357,
#  'uploading': 172,
#  'friendster': 47,
#  'ash': 102,
#  'ct': 57,
#  'pic': 2013,
#  'p': 2916,
#  'noodlebox': 1,
#  'amanda': 128,
#  'una': 20,
#  'avion': 3,
#  'sorrry': 3,
#  'different': 425,
#  'thing': 4099,
#  'kevin': 138,
#  'jonas': 495,
#  'girlfriend': 194,
#  'fuzeb': 1,
#  'serious': 237,
#  'singing': 389,
#  'whoa': 131,
#  'hehe': 1340,
#  'lsd': 2,
#  'maybe': 2183,
#  'j': 863,
#  'k': 1133,
#  'lolol': 52,
#  'loving': 802,
#  'apothecaryjeri': 5,
#  'sicilian': 4,
#  'damn': 770,
#  'pizza': 377,
#  'planet': 116,
#  'chocolate': 658,
#  'milk': 231,
#  'gf': 84,
#  'sutter': 2,
#  'creek': 31,
#  'tour': 514,
#  'old': 1815,
#  'bodycoach': 1,
#  'look': 4164,
#  'cho': 25,
#  'personally': 90,
#  'strawberry': 193,
#  'become': 219,
#  'coach': 75,
#  'soon': 2963,
#  'little': 2668,
#  'fish': 206,
#  'guess': 1493,
#  'live': 1605,
#  'side': 533,
#  'earth': 228,
#  'east': 124,
#  'mesa': 10,
#  'losiento': 1,
#  'paula': 46,
#  'paige': 33,
#  'apart': 108,
#  'sore': 141,
#  'tryout': 42,
#  'failed': 63,
#  'physic': 53,
#  'test': 511,
#  'homo': 18,
#  'keeen': 1,
#  'holiday': 725,
#  'observed': 6,
#  'update': 1068,
#  'alexa': 25,
#  'website': 494,
#  'tinyurl': 1982,
#  'c': 1608,
#  'gzf': 1,
#  'seems': 618,
#  'improving': 25,
#  'leiabox': 2,
#  'totally': 1042,
#  'geeking': 5,
#  'right': 3945,
#  'theragingocean': 2,
#  'bonjour': 29,
#  'spacecowboy': 1,
#  'wish': 2123,
#  'either': 581,
#  'work': 7097,
#  'kid': 1297,
#  'whenever': 124,
#  'want': 4269,
#  'wherever': 48,
#  'rebecca': 52,
#  'brother': 798,
#  'quite': 879,
#  'weird': 467,
#  'drdrew': 3,
#  'give': 1685,
#  'hug': 695,
#  'cookie': 116,
#  'hey': 4421,
#  'take': 2895,
#  'care': 861,
#  'rundown': 3,
#  'wrote': 232,
#  'wall': 212,
#  'correct': 122,
#  'poor': 232,
#  'spelling': 85,
#  'highlighter': 2,
#  'wash': 129,
#  'hardcore': 63,
#  'good': 20273,
#  'tech': 138,
#  'clubzone': 2,
#  'sushi': 161,
#  'mattgalloway': 2,
#  'carlyrush': 1,
#  'suggesting': 10,
#  'bro': 369,
#  'rock': 1216,
#  'jeffswarens': 1,
#  'depends': 123,
#  'version': 364,
#  'thought': 1943,
#  'speak': 292,
#  'ashley': 139,
#  'hand': 654,
#  'still': 4504,
#  'pretty': 2420,
#  'weak': 56,
#  'punch': 63,
#  'anyone': 1035,
#  'yet': 1479,
#  'turn': 563,
#  'knob': 4,
#  'doesnt': 187,
#  'honey': 251,
#  'lurker': 7,
#  'interesting': 804,
#  'saravananp': 2,
#  'b': 1940,
#  'north': 164,
#  'need': 4907,
#  'decide': 152,
#  'aaru': 1,
#  'hithavaru': 1,
#  'ninage': 1,
#  'ee': 34,
#  'moovarolage': 1,
#  'vote': 385,
#  'trstfndbby': 1,
#  'um': 220,
#  'bought': 768,
#  'shit': 614,
#  'korean': 47,
#  'oach': 1,
#  'highest': 25,
#  'quality': 189,
#  'baby': 1655,
#  'paid': 204,
#  'extra': 290,
#  'tag': 112,
#  'sewed': 4,
#  'eating': 1133,
#  'ice': 608,
#  'cream': 545,
#  'topping': 19,
#  'iamdiddy': 129,
#  'telling': 194,
#  'finished': 1328,
#  'crunch': 42,
#  'step': 277,
#  'diddy': 49,
#  'yvonne': 10,
#  'daaang': 1,
#  'possible': 252,
#  'lauruy': 1,
#  'west': 176,
#  'mostly': 169,
#  'san': 189,
#  'jose': 33,
#  'francisco': 27,
#  'nikki': 68,
#  'working': 1891,
#  'bike': 347,
#  'trying': 1427,
#  'recover': 23,
#  'knee': 85,
#  'injury': 22,
#  'marymayblood': 1,
#  'would': 4224,
#  'help': 1859,
#  'unpack': 8,
#  'sat': 329,
#  'afternoon': 785,
#  'shenagians': 1,
#  'team': 539,
#  'awesome': 4576,
#  'listening': 1726,
#  'music': 1956,
#  'chilling': 193,
#  'regret': 64,
#  'done': 2614,
#  'till': 979,
#  'kick': 341,
#  'study': 433,
#  'amp': 8014,
#  'grow': 141,
#  'rich': 114,
#  'wow': 2135,
#  'amazing': 2739,
#  'timeless': 11,
#  'law': 222,
#  'attraction': 17,
#  'program': 127,
#  'bittenbybooks': 4,
#  'oh': 5485,
#  'week': 4071,
#  'though': 2965,
#  'chris': 325,
#  'home': 5068,
#  'summer': 1248,
#  'davidgideon': 2,
#  'ish': 165,
#  'therealjspace': 2,
#  'tweet': 3719,
#  'drinking': 516,
#  'anne': 67,
#  'kay': 105,
#  'determined': 46,
#  'baseball': 110,
#  'year': 2252,
#  'since': 1066,
#  'watched': 883,
#  'sport': 162,
#  'interested': 249,
#  'game': 1663,
#  'beycah': 1,
#  'becca': 25,
#  'missnappyboy': 1,
#  'ohhh': 155,
#  'nkow': 1,
#  'lexington': 5,
#  'ky': 38,
#  'rite': 78,
#  'next': 3052,
#  'seen': 913,
#  'preview': 56,
#  'movie': 2848,
#  'obsessed': 108,
#  'w': 1914,
#  'beyonce': 50,
#  'broad': 13,
#  'nut': 138,
#  'easy': 578,
#  'rider': 34,
#  'fall': 401,
#  'asleep': 407,
#  'miketomalaris': 1,
#  'excited': 2146,
#  'broadcast': 39,
#  'paris': 160,
#  'roubaix': 1,
#  'moment': 553,
#  'missssssssss': 1,
#  'belliestobabies': 1,
#  'people': 3369,
#  'survive': 67,
#  'winter': 138,
#  'without': 698,
#  'jungle': 31,
#  'gym': 497,
#  'jaredleto': 23,
#  'started': 684,
#  'last': 4371,
#  'holidayholiday': 1,
#  'watchin': 258,
#  'greek': 84,
#  'knighty': 8,
#  'medium': 269,
#  'design': 395,
#  'client': 227,
#  'profile': 422,
#  'lame': 181,
#  'stalk': 57,
#  'sexy': 374,
#  'lou': 49,
#  'aww': 944,
#  'another': 2027,
#  'nitey': 15,
#  'nite': 862,
#  'ahh': 480,
#  'kinda': 764,
#  'nervous': 138,
#  'til': 489,
#  'planning': 317,
#  'whatever': 401,
#  'happier': 87,
#  'hopin': 17,
#  'fb': 450,
#  'store': 448,
#  'missvic': 1,
#  'mean': 1589,
#  'jimmyeatworld': 5,
#  'www': 2017,
#  'deezer': 3,
#  'track': 370,
#  'urbanthai': 1,
#  'thank': 5126,
#  'pamfr': 1,
#  'pam': 40,
#  'yes': 4080,
#  'short': 613,
#  'struggle': 21,
#  'choice': 272,
#  'every': 1127,
#  'hmm': 513,
#  'lot': 2589,
#  'course': 1047,
#  'late': 1163,
#  'reading': 1041,
#  'guykawasaki': 14,
#  'follower': 1520,
#  'almost': 1090,
#  'larrycarroll': 1,
#  'nm': 35,
#  'screaming': 64,
#  'wondering': 357,
#  'freakin': 134,
#  'cooool': 18,
#  'renda': 1,
#  'nothing': 1343,
#  'wrong': 580,
#  'caring': 41,
#  'try': 2007,
#  'brissa': 1,
#  'lauren': 105,
#  'jbrotherlove': 1,
#  'story': 637,
#  'enbaldarlingg': 1,
#  'mirror': 61,
#  'looking': 2530,
#  'amandahesser': 1,
#  'neat': 76,
#  'god': 1688,
#  'overitnow': 1,
#  'apologize': 31,
#  'sharing': 311,
#  'spiritual': 27,
#  'general': 108,
#  'public': 153,
#  'leave': 743,
#  'ontario': 15,
#  'spoke': 50,
#  'fam': 296,
#  'japan': 73,
#  'via': 593,
#  'skype': 119,
#  'mo': 222,
#  'nephew': 111,
#  'growing': 115,
#  'lissym': 1,
#  'saw': 1585,
#  'written': 115,
#  'someone': 1326,
#  'spoken': 27,
#  'suck': 593,
#  'mcfly': 353,
#  'loser': 114,
#  'kacimaureen': 1,
#  'holy': 194,
#  'laundry': 176,
#  'woman': 511,
#  'hate': 912,
#  'trainer': 44,
#  'markhoppus': 80,
#  'fucking': 328,
#  'funny': 1638,
#  'setting': 192,
#  'touch': 337,
#  'officially': 302,
#  'nikhilnarayanan': 8,
#  'tvc': 2,
#  'yesterday': 1396,
#  'worked': 316,
#  'could': 2574,
#  'mannies': 1,
#  'peddies': 1,
#  'shut': 208,
#  'fat': 188,
#  'face': 809,
#  'magopus': 1,
#  'ever': 1918,
#  'run': 928,
#  'idea': 1230,
#  'nominating': 1,
#  'beer': 488,
#  'monday': 1481,
#  'never': 2086,
#  'always': 2594,
#  'hopeinhell': 7,
#  'usually': 261,
#  'follows': 88,
#  'special': 606,
#  'luck': 1763,
#  'rest': 866,
#  'cast': 90,
#  'tb': 60,
#  'something': 2138,
#  'leak': 13,
#  'land': 216,
#  'among': 34,
#  'johnhays': 1,
#  'agree': 670,
#  'entirely': 41,
#  'creative': 159,
#  'vibrant': 5,
#  'reason': 530,
#  'izzakizza': 1,
#  'nada': 23,
#  'holla': 89,
#  'hows': 238,
#  'mixtape': 23,
#  'coming': 1612,
#  'aussie': 128,
#  'ali': 87,
#  'yep': 644,
#  'easier': 226,
#  'point': 613,
#  'snarkattack': 8,
#  'freezer': 23,
#  'worthy': 46,
#  'amoir': 2,
#  'given': 160,
#  'scholarly': 4,
#  'attention': 152,
#  'suppose': 176,
#  'set': 662,
#  'eye': 694,
#  'jf': 14,
#  'cupcake': 201,
#  'purrplexa': 1,
#  'wonderful': 1114,
#  'favor': 71,
#  'using': 551,
#  'entire': 145,
#  'english': 476,
#  'language': 132,
#  'use': 1372,
#  'expletive': 2,
#  'mynameisgerard': 1,
#  'saying': 513,
#  'walk': 706,
#  'flippin': 17,
#  'cold': 611,
#  'outside': 781,
#  'ago': 692,
#  'sunny': 864,
#  'raining': 319,
#  'snowing': 15,
#  'sisterpatterson': 1,
#  'ate': 323,
#  'raw': 47,
#  'dough': 30,
#  'tub': 38,
#  'must': 1370,
#  'kindred': 8,
#  'spirit': 131,
#  'internet': 460,
#  'dirty': 126,
#  'nighty': 138,
#  'bloom': 17,
#  'tweetdeck': 234,
#  'facebook': 856,
#  'firestoned': 1,
#  'dude': 800,
#  'surprised': 180,
#  'tweeting': 562,
#  'nsastrasasmita': 1,
#  'figure': 397,
#  'llama': 8,
#  'malcolm': 2,
#  'megan': 72,
#  'fuck': 413,
#  'theatre': 64,
#  'kayotae': 1,
#  'martini': 30,
#  'city': 677,
#  'soo': 629,
#  'spring': 339,
#  'break': 675,
#  'watching': 4031,
#  'moviess': 4,
#  'everyday': 203,
#  'pushplaynick': 3,
#  'grandpa': 43,
#  'chest': 36,
#  'beef': 60,
#  'george': 117,
#  'lopez': 28,
#  'rulesss': 1,
#  'katieporrello': 2,
#  'katie': 115,
#  'heading': 747,
#  'club': 413,
#  'stellar': 23,
#  'homey': 5,
#  'youtube': 823,
#  'v': 964,
#  'cle': 7,
#  'pjsras': 1,
#  'flower': 264,
#  'gone': 563,
#  'peter': 95,
#  'paul': 220,
#  'mary': 144,
#  'fav': 297,
#  'def': 242,
#  'shhhhhhhhhh': 1,
#  'posting': 179,
#  'photo': 1099,
#  'hit': 759,
#  'count': 276,
#  'china': 86,
#  'view': 301,
#  'alone': 317,
#  'came': 810,
#  'appreciate': 456,
#  'lonelybob': 5,
#  'everywhere': 149,
#  'provided': 21,
#  'broadband': 17,
#  'kiddin': 21,
#  'callin': 22,
#  'infinitarchitek': 1,
#  'stee': 1,
#  'hash': 29,
#  'bash': 25,
#  'anyway': 748,
#  'loltothepower': 1,
#  'correction': 48,
#  'badass': 41,
#  'fringe': 40,
#  'procoder': 3,
#  'hmmm': 363,
#  'upto': 22,
#  'ninasplayground': 3,
#  'christmas': 81,
#  'bn': 16,
#  'fun': 5753,
#  'caught': 230,
#  'yrold': 3,
#  'cheating': 22,
#  'reflection': 19,
#  'tv': 1000,
#  'hair': 1147,
#  'blue': 492,
#  'wendy': 44,
#  'bowser': 2,
#  'kind': 940,
#  'word': 1158,
#  'stressing': 14,
#  'math': 318,
#  'uhhh': 17,
#  'mintcool': 1,
#  'uh': 198,
#  'designated': 8,
#  'driver': 118,
#  'pch': 4,
#  'empressyen': 1,
#  'whatcha': 34,
#  'chucklin': 1,
#  'bout': 583,
#  'm': 237,
#  'yen': 13,
#  'ijustine': 34,
#  'augustography': 1,
#  'climbing': 39,
#  'sining': 2,
#  'unc': 15,
#  'prepare': 75,
#  'g': 1198,
#  'keyannaaa': 1,
#  'include': 55,
#  'magic': 242,
#  'fountain': 30,
#  'trip': 866,
#  'boring': 328,
#  'trusty': 6,
#  'book': 1447,
#  'anastasia': 7,
#  'laptop': 364,
#  'ff': 501,
#  'top': 661,
#  'buzzing': 13,
#  'sietar': 1,
#  'pattidigh': 8,
#  'pushing': 51,
#  'boundary': 24,
#  'boy': 1449,
#  'money': 687,
#  'manual': 24,
#  'yoshigi': 1,
#  'terrible': 86,
#  'neck': 79,
#  'ache': 47,
#  'chair': 91,
#  'waiting': 1281,
#  'swopper': 1,
#  'arrive': 103,
#  'juneaurock': 1,
#  'hellz': 8,
#  'definitely': 800,
#  'downloading': 157,
#  'jz': 10,
#  'stinkin': 14,
#  'cute': 1730,
#  'lyndeeezy': 1,
#  'hahah': 374,
#  'blog': 1419,
#  'nice': 5630,
#  'recent': 64,
#  'popular': 98,
#  'listed': 34,
#  'together': 640,
#  'michaelgrainger': 46,
#  ...}

# %%
#Counting the word and values

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
count_corpus
# Out:
#                 word  count
# 485             good  20273
# 84               day  19789
# 0               love  14969
# 181             http  14800
# 196             quot  14567
# ...              ...    ...
# 80922   dylanjthomas      1
# 80921      dignified      1
# 80920          kajol      1
# 80919        archana      1
# 170984   terminiator      1
#
# [170985 rows x 2 columns]

# %%
#Barplot for positive word

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in positive data')
plt.show()

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    #dic = dict(sorted(dic.items() , key = lambda x:x[1],reverse=True))
    return(dic)
count_corpus = get_count(negative_list)

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
count_corpus
# Out:
#                 word  count
# 121              day  16282
# 14               get  15058
# 58                go  14950
# 142             work  14629
# 18              like  12906
# ...              ...    ...
# 70129         shaawe      1
# 70128        beboooo      1
# 70127        nisunis      1
# 70126            ood      1
# 144552  aarondelgado      1
#
# [144553 rows x 2 columns]

# %%
#Barplot for negative word

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in negative data')
plt.grid(True,  linestyle="--", linewidth=0.5, alpha=0.5)  # Grid for better readability
plt.show()

# %% [markdown]
# **Inference**
# * Positive data has words like good, day, thanks, great, happy
# * Negative data has words like work, miss, sad etc

# %% [markdown]
# ## Classification
# ### Naive bayes for sentiment analysis

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_list)
negative_tokens_for_model = get_tweets_for_model(negative_list)

# %%
positive_tokens_for_model
# Out:
# <generator object get_tweets_for_model at 0x000002B7A12B7220>

# %%
import random

positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]
dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_size = int(len(dataset)*0.666)
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# %%
train_data[1]
# Out:
# ({'feel': True,
#   'sad': True,
#   'mike': True,
#   'tyson': True,
#   'tragedy': True,
#   'http': True,
#   'raymond': True,
#   'review': True,
#   'blogspot': True,
#   'com': True},
#  'Negative')

# %%
print("Sample test data:")
for i in range(5):  # Print first 5 test samples
    print(test_data[i])
# Out:
# Sample test data:
# ({'sounder': True, 'columbus': True, 'crew': True, 'half': True}, 'Negative')
# ({'kassymay': True, 'lol': True, 'know': True, 'like': True, 'tonight': True}, 'Negative')
# ({'slough': True, 'oh': True, 'btw': True, 'would': True, 'love': True, 'hang': True, 'nyc': True, 'unfortunately': True, 'mile': True, 'right': True}, 'Negative')
# ({'life': True, 'beautiful': True}, 'Positive')
# ({'time': True, 'head': True, 'dream': True, 'land': True, 'hittin': True, 'big': True, 'city': True, 'first': True, 'two': True, 'year': True, 'tomorrow': True, 'best': True, 'friend': True, 'wait': True}, 'Positive')

# %% [markdown]
# ### For positve and negative dataset train & test preview

# %%
dataset
# Out:
# [({'mickelbetch': True,
#    'love': True,
#    'song': True,
#    'actually': True,
#    'old': True,
#    'p': True,
#    'atd': True,
#    'patd': True,
#    'haha': True,
#    'camisado': True,
#    'still': True,
#    'favourite': True},
#   'Positive'),
#  ({'feel': True,
#    'sad': True,
#    'mike': True,
#    'tyson': True,
#    'tragedy': True,
#    'http': True,
#    'raymond': True,
#    'review': True,
#    'blogspot': True,
#    'com': True},
#   'Negative'),
#  ({'contemplating': True,
#    'rude': True,
#    'phone': True,
#    'feel': True,
#    'bad': True},
#   'Negative'),
#  ({'sleep': True, 'hate': True}, 'Negative'),
#  ({'stcyrlyme': True,
#    'people': True,
#    'always': True,
#    'say': True,
#    'thank': True,
#    'armed': True,
#    'force': True,
#    'service': True,
#    'want': True,
#    'country': True},
#   'Positive'),
#  ({'woke': True,
#    'body': True,
#    'told': True,
#    'smile': True,
#    'crossed': True,
#    'face': True},
#   'Positive'),
#  ({'check': True,
#    'new': True,
#    'profile': True,
#    'pic': True,
#    'people': True,
#    'didnt': True,
#    'take': True,
#    'long': True,
#    'circular': True,
#    'thing': True,
#    'face': True,
#    'annoying': True},
#   'Negative'),
#  ({'done': True, 'tired': True, 'body': True, 'ache': True}, 'Positive'),
#  ({'hilzfuld': True}, 'Positive'),
#  ({'listening': True,
#    'toooooo': True,
#    'green': True,
#    'day': True,
#    'viva': True,
#    'la': True,
#    'gloria': True,
#    'little': True,
#    'girl': True},
#   'Positive'),
#  ({'school': True}, 'Negative'),
#  ({'anddd': True,
#    'finally': True,
#    'san': True,
#    'antonio': True,
#    'amp': True,
#    'bum': True,
#    'rush': True,
#    'grandparent': True},
#   'Positive'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'm': True,
#    'cupcake': True,
#    'made': True,
#    'esther': True,
#    'b': True,
#    'day': True},
#   'Positive'),
#  ({'next': True,
#    'week': True,
#    'going': True,
#    'hell': True,
#    'today': True,
#    'watched': True,
#    'let': True,
#    'right': True,
#    'one': True,
#    'amazing': True,
#    'highly': True,
#    'recommended': True,
#    'studying': True},
#   'Negative'),
#  ({'wow': True, 'heather': True}, 'Positive'),
#  ({'minute': True, 'power': True, 'nap': True, 'da': True, 'bomb': True},
#   'Positive'),
#  ({'willsexy': True,
#    'thanks': True,
#    'man': True,
#    'keep': True,
#    'playing': True,
#    'rocking': True,
#    'as': True,
#    'show': True,
#    'long': True},
#   'Positive'),
#  ({'need': True,
#    'sleep': True,
#    'get': True,
#    'early': True,
#    'tomorrow': True,
#    'prepare': True,
#    'birthday': True,
#    'party': True,
#    'happy': True,
#    'baby': True,
#    'bro': True,
#    'si': True},
#   'Positive'),
#  ({'officialtila': True,
#    'u': True,
#    'say': True,
#    'read': True,
#    'respond': True,
#    'everyone': True,
#    'message': True,
#    'ignored': True,
#    'uncle': True,
#    'farkus': True,
#    'last': True,
#    'one': True},
#   'Negative'),
#  ({'iar': True,
#    'face': True,
#    'tatal': True,
#    'meu': True,
#    'misto': True,
#    'de': True,
#    'mine': True,
#    'pt': True,
#    'k': True,
#    'parul': True,
#    'blond': True,
#    'zice': True,
#    'ca': True,
#    'blondele': True,
#    'naturale': True,
#    'sunt': True,
#    'pe': True,
#    'cale': True,
#    'disparitie': True,
#    'desteptat': True,
#    'lumea': True},
#   'Positive'),
#  ({'im': True,
#    'feeling': True,
#    'really': True,
#    'good': True,
#    'today': True,
#    'slept': True,
#    'woke': True,
#    'pm': True,
#    'dream': True},
#   'Positive'),
#  ({'one': True,
#    'exam': True,
#    'left': True,
#    'w': True,
#    'negative': True,
#    'side': True,
#    'bloody': True,
#    'exhaused': True,
#    'math': True,
#    'think': True,
#    'going': True},
#   'Negative'),
#  ({'love': True, 'big': True, 'twit': True}, 'Positive'),
#  ({'bradhfh': True,
#    'suck': True,
#    'give': True,
#    'needle': True,
#    'scared': True,
#    'drugging': True,
#    'take': True,
#    'advantage': True,
#    'alone': True,
#    'big': True,
#    'chair': True},
#   'Negative'),
#  ({'iegg': True, 'sir': True, 'stuck': True, 'work': True, 'till': True},
#   'Negative'),
#  ({'laurasauruss': True,
#    'favorite': True,
#    'one': True,
#    'rob': True,
#    'hoffman': True,
#    'tweeted': True,
#    'left': True,
#    'u': True},
#   'Negative'),
#  ({'frontporchlife': True,
#    'hahah': True,
#    'okay': True,
#    'lol': True,
#    'posted': True,
#    'itt': True},
#   'Negative'),
#  ({'jjblackshear': True, 'holy': True, 'crap': True}, 'Negative'),
#  ({'jonasbrothers': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'ol': True,
#    'line': True,
#    'vine': True,
#    'trying': True,
#    'time': True,
#    'gonna': True,
#    'suck': True,
#    'awesome': True,
#    'cd': True,
#    'iloveyou': True},
#   'Positive'),
#  ({'wow': True, 'pulled': True, 'string': True, 'tonight': True}, 'Positive'),
#  ({'kevin': True,
#    'anr': True,
#    'shine': True,
#    'man': True,
#    'u': True,
#    'reply': True,
#    'email': True,
#    'know': True},
#   'Positive'),
#  ({'tiny': True,
#    'cut': True,
#    'underneath': True,
#    'findernail': True,
#    'hurt': True,
#    'like': True,
#    'hell': True,
#    'owie': True},
#   'Negative'),
#  ({'electrophile': True, 'fixed': True, 'thanks': True}, 'Positive'),
#  ({'hanging': True, 'hannah': True, 'go': True, 'clean': True}, 'Negative'),
#  ({'sirvinya': True,
#    'yes': True,
#    'would': True,
#    'great': True,
#    'except': True,
#    'go': True,
#    'cosmetic': True,
#    'manufacturer': True,
#    'black': True,
#    'xxx': True},
#   'Negative'),
#  ({'jasminedarkly': True,
#    'yuck': True,
#    'easy': True,
#    'way': True,
#    'stand': True,
#    'people': True,
#    'make': True,
#    'effort': True,
#    'try': True,
#    'understand': True},
#   'Negative'),
#  ({'camera': True, 'nott': True, 'workingngngngnng': True, 'cry': True},
#   'Negative'),
#  ({'love': True, 'happy': True, 'mother': True, 'day': True}, 'Positive'),
#  ({'still': True,
#    'nice': True,
#    'conversation': True,
#    'friend': True,
#    'inspirational': True,
#    'always': True,
#    'pesky': True,
#    'goblin': True},
#   'Positive'),
#  ({'ror': True, 'fonctionnel': True, 'fun': True}, 'Positive'),
#  ({'gracethomo': True,
#    'naaaaaaaaaaa': True,
#    'co': True,
#    'hosting': True,
#    'twas': True,
#    'funny': True},
#   'Positive'),
#  ({'cleaning': True, 'fun': True}, 'Negative'),
#  ({'tisza': True,
#    'happy': True,
#    'big': True,
#    'ol': True,
#    'coyote': True,
#    'git': True,
#    'thanks': True,
#    'daddy': True,
#    'http': True,
#    'apps': True,
#    'facebook': True,
#    'com': True,
#    'dogbook': True,
#    'profile': True,
#    'view': True},
#   'Positive'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'iycm': True,
#    'baby': True,
#    'girl': True,
#    'niece': True,
#    'heart': True},
#   'Positive'),
#  ({'shit': True,
#    'like': True,
#    'im': True,
#    'toilet': True,
#    'lik': True,
#    'yuupp': True,
#    'lol': True},
#   'Positive'),
#  ({'mhawthorne': True,
#    'oh': True,
#    'totally': True,
#    'forgot': True,
#    'played': True,
#    'today': True},
#   'Negative'),
#  ({'graphiclucidity': True,
#    'really': True,
#    'obviously': True,
#    'love': True,
#    'dark': True,
#    'day': True,
#    'go': True,
#    'air': True},
#   'Negative'),
#  ({'watch': True,
#    'run': True,
#    'every': True,
#    'cute': True,
#    'guy': True,
#    'campus': True,
#    'dressed': True,
#    'like': True,
#    'slob': True,
#    'b': True,
#    'c': True,
#    'always': True,
#    'happens': True},
#   'Negative'),
#  ({'relaxing': True,
#    'home': True,
#    'listening': True,
#    'chesterfrench': True,
#    'debating': True,
#    'hit': True,
#    'gym': True,
#    'bit': True},
#   'Negative'),
#  ({'half': True,
#    'awake': True,
#    'still': True,
#    'thinking': True,
#    'nonsense': True,
#    'want': True,
#    'red': True,
#    'jello': True,
#    'reasson': True},
#   'Positive'),
#  ({'dont': True, 'understand': True}, 'Negative'),
#  ({'looking': True,
#    'forward': True,
#    'spending': True,
#    'time': True,
#    'mom': True,
#    'today': True},
#   'Positive'),
#  ({'cake': True, 'keyboard': True}, 'Negative'),
#  ({'raining': True,
#    'pouring': True,
#    'old': True,
#    'man': True,
#    'snoring': True,
#    'went': True,
#    'bed': True,
#    'bump': True,
#    'head': True,
#    'couldnt': True,
#    'get': True,
#    'morning': True},
#   'Positive'),
#  ({'mister': True,
#    'peterman': True,
#    'paid': True,
#    'almost': True,
#    'twice': True,
#    'fly': True,
#    'back': True,
#    'next': True,
#    'week': True,
#    'think': True,
#    'sale': True,
#    'fare': True,
#    'start': True,
#    'later': True},
#   'Negative'),
#  ({'unicorn': True,
#    'oh': True,
#    'sound': True,
#    'seems': True,
#    'like': True,
#    'good': True,
#    'ep': True,
#    'cant': True,
#    'wait': True,
#    'see': True},
#   'Positive'),
#  ({'serenebella': True,
#    'name': True,
#    'condition': True,
#    'probably': True,
#    'gonna': True,
#    'hafta': True,
#    'get': True,
#    'soon': True,
#    'b': True,
#    'c': True,
#    'lap': True,
#    'top': True,
#    'charger': True,
#    'upstairs': True},
#   'Negative'),
#  ({'kirstiealley': True,
#    'sweetie': True,
#    'hmmm': True,
#    'still': True,
#    'plotting': True,
#    'kidnap': True,
#    'person': True,
#    'eyebrow': True,
#    'get': True,
#    'mine': True,
#    'arch': True},
#   'Negative'),
#  ({'totally': True, 'creepy': True, 'cameron': True, 'tonight': True},
#   'Negative'),
#  ({'prom': True,
#    'crackin': True,
#    'thanks': True,
#    'bubba': True,
#    'ria': True,
#    'brina': True,
#    'boofriends': True,
#    'great': True,
#    'company': True,
#    'waking': True,
#    'face': True,
#    'night': True},
#   'Positive'),
#  ({'dongle': True,
#    'tuesday': True,
#    'even': True,
#    'stephen': True,
#    'going': True,
#    'come': True,
#    'ear': True},
#   'Negative'),
#  ({'oddlittleducky': True,
#    'let': True,
#    'people': True,
#    'stress': True,
#    'either': True},
#   'Positive'),
#  ({'weird': True,
#    'dream': True,
#    'last': True,
#    'night': True,
#    'boat': True,
#    'pool': True,
#    'cut': True,
#    'half': True,
#    'chainsaw': True,
#    'everyone': True,
#    'sank': True,
#    'bottom': True,
#    'realhughjackman': True,
#    'amp': True,
#    'saved': True},
#   'Positive'),
#  ({'head': True,
#    'amp': True,
#    'shoulder': True,
#    'comercial': True,
#    'today': True},
#   'Positive'),
#  ({'watching': True, 'film': True, 'alone': True}, 'Negative'),
#  ({'djp': True,
#    'rez': True,
#    'woot': True,
#    'hope': True,
#    'u': True,
#    'safe': True,
#    'flight': True,
#    'excited': True,
#    'make': True,
#    'sure': True,
#    'eat': True,
#    'sum': True,
#    'tex': True,
#    'mex': True,
#    'bbq': True,
#    'r': True,
#    'rock': True},
#   'Positive'),
#  ({'histapleface': True,
#    'hahahaha': True,
#    'oh': True,
#    'yes': True,
#    'get': True,
#    'giant': True,
#    'projector': True,
#    'like': True,
#    'watch': True,
#    'movie': True,
#    'front': True,
#    'tent': True,
#    'everyone': True,
#    'jealous': True},
#   'Positive'),
#  ({'supermac': True,
#    'u': True,
#    'swine': True,
#    'flue': True,
#    'might': True,
#    'die': True},
#   'Negative'),
#  ({'dang': True,
#    'r': True,
#    'foot': True,
#    'reconstructed': True,
#    'calf': True,
#    'muscle': True,
#    'cut': True,
#    'working': True,
#    'fault': True},
#   'Negative'),
#  ({'gregori': True,
#    'cool': True,
#    'thanks': True,
#    'making': True,
#    'trip': True,
#    'mate': True,
#    'glad': True,
#    'getting': True,
#    'copy': True,
#    'life': True,
#    'treating': True,
#    'day': True,
#    'amigo': True},
#   'Positive'),
#  ({'dark': True, 'side': True, 'friend': True, 'twitter': True}, 'Negative'),
#  ({'realkidpoker': True,
#    'thought': True,
#    'actually': True,
#    'talking': True,
#    'u': True},
#   'Negative'),
#  ({'watching': True,
#    'run': True,
#    'series': True,
#    'three': True,
#    'grey': True,
#    'anatomy': True,
#    'always': True,
#    'make': True,
#    'cry': True,
#    'christina': True,
#    'left': True,
#    'alter': True},
#   'Negative'),
#  ({'njvinnie': True, 'mean': True, 'joining': True, 'killathons': True},
#   'Positive'),
#  ({'sun': True,
#    'ironed': True,
#    'white': True,
#    'jean': True,
#    'took': True,
#    'age': True,
#    'hope': True,
#    'worth': True,
#    'fine': True,
#    'line': True,
#    'mutton': True,
#    'lamb': True},
#   'Positive'),
#  ({'kachwanya': True, 'thanks': True, 'bro': True}, 'Positive'),
#  ({'ickleinnocentme': True, 'get': True, 'sleep': True, 'sawahbear': True},
#   'Negative'),
#  ({'recovering': True,
#    'another': True,
#    'failed': True,
#    'flight': True,
#    'experience': True},
#   'Negative'),
#  ({'clearly': True, 'chamala': True, 'went': True, 'sleep': True}, 'Negative'),
#  ({'queenzgoddess': True, 'common': True, 'knowledge': True}, 'Positive'),
#  ({'themomjen': True,
#    'oldest': True,
#    'pit': True,
#    'afraid': True,
#    'last': True,
#    'summer': True,
#    'u': True,
#    'poor': True,
#    'old': True,
#    'man': True,
#    'email': True},
#   'Negative'),
#  ({'loving': True,
#    'sunshine': True,
#    'slept': True,
#    'life': True,
#    'general': True},
#   'Positive'),
#  ({'need': True, 'westley': True, 'come': True, 'save': True}, 'Negative'),
#  ({'ooooh': True, 'great': True, 'idea': True, 'hmm': True, 'start': True},
#   'Positive'),
#  ({'lord': True,
#    'also': True,
#    'know': True,
#    'rite': True,
#    'abt': True,
#    'craving': True,
#    'cinabon': True},
#   'Negative'),
#  ({'muzikgurl': True, 'sad': True}, 'Negative'),
#  ({'pinkie': True, 'pie': True, 'thanks': True, 'sweet': True, 'girl': True},
#   'Positive'),
#  ({'home': True,
#    'buzzed': True,
#    'hubby': True,
#    'dislocated': True,
#    'knee': True,
#    'paying': True,
#    'rock': True,
#    'band': True,
#    'power': True,
#    'stance': True,
#    'as': True,
#    'blame': True,
#    'mexicore': True},
#   'Positive'),
#  ({'luwees': True,
#    'denny': True,
#    'open': True,
#    'night': True,
#    'though': True,
#    'ihop': True},
#   'Negative'),
#  ({'sunshineodt': True, 'awww': True, 'thanks': True}, 'Positive'),
#  ({'millie': True,
#    'party': True,
#    'fun': True,
#    'last': True,
#    'nightttt': True,
#    'im': True,
#    'gunna': True,
#    'miss': True,
#    'senior': True,
#    'lt': True},
#   'Negative'),
#  ({'djkidav': True, 'make': True, 'laugh': True}, 'Positive'),
#  ({'drinkin': True,
#    'chai': True,
#    'tea': True,
#    'sleeping': True,
#    'checkin': True,
#    'cool': True,
#    'peep': True},
#   'Positive'),
#  ({'drag': True,
#    'hell': True,
#    'scary': True,
#    'screamed': True,
#    'throughout': True,
#    'da': True,
#    'whole': True,
#    'movie': True,
#    'expcted': True,
#    'shit': True,
#    'stupid': True,
#    'like': True,
#    'othr': True,
#    'recent': True,
#    'flick': True},
#   'Negative'),
#  ({'jmonroe': True,
#    'actually': True,
#    'went': True,
#    'move': True,
#    'jeep': True,
#    'battery': True,
#    'dead': True,
#    'sad': True,
#    'face': True},
#   'Negative'),
#  ({'wishing': True, 'home': True}, 'Negative'),
#  ({'bfheroes': True,
#    'sys': True,
#    'admin': True,
#    'shame': True,
#    'sweden': True},
#   'Negative'),
#  ({'wondering': True,
#    'someone': True,
#    'follow': True,
#    'come': True,
#    'bite': True,
#    'say': True,
#    'hi': True},
#   'Positive'),
#  ({'go': True, 'ready': True, 'yet': True, 'idiot': True}, 'Negative'),
#  ({'gfalcone': True,
#    'want': True,
#    'cat': True,
#    'would': True,
#    'call': True,
#    'timothy': True,
#    'mum': True,
#    'hate': True},
#   'Negative'),
#  ({'darby': True,
#    'totally': True,
#    'want': True,
#    'miss': True,
#    'much': True,
#    'love': True},
#   'Negative'),
#  ({'superspence': True,
#    'condo': True,
#    'home': True,
#    'til': True,
#    'monday': True},
#   'Negative'),
#  ({'new': True,
#    'book': True,
#    'sigh': True,
#    'probably': True,
#    'reread': True,
#    'gaiman': True,
#    'quot': True,
#    'american': True,
#    'god': True,
#    'murakami': True,
#    'wind': True,
#    'bird': True,
#    'chronicle': True},
#   'Positive'),
#  ({'crooklynn': True, 'yes': True, 'im': True, 'mad': True, 'bee': True},
#   'Negative'),
#  ({'yeah': True,
#    'yesterday': True,
#    'turned': True,
#    'parent': True,
#    'rented': True,
#    'hummer': True,
#    'limo': True,
#    'pretty': True,
#    'cool': True},
#   'Positive'),
#  ({'walk': True, 'remember': True, 'made': True, 'cry': True}, 'Negative'),
#  ({'first': True,
#    'day': True,
#    'back': True,
#    'work': True,
#    'since': True,
#    'last': True,
#    'wednesday': True,
#    'iv': True,
#    'realised': True,
#    'much': True,
#    'fuckin': True,
#    'hate': True,
#    'job': True},
#   'Negative'),
#  ({'called': True,
#    'name': True,
#    'saw': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'yvdma': True,
#    'stupid': True},
#   'Negative'),
#  ({'watched': True,
#    'britain': True,
#    'got': True,
#    'talent': True,
#    'last': True,
#    'night': True,
#    'even': True,
#    'pierce': True,
#    'morgan': True,
#    'soft': True,
#    'spot': True,
#    'belly': True,
#    'button': True,
#    'one': True,
#    'act': True,
#    'asked': True,
#    'display': True},
#   'Positive'),
#  ({'omg': True,
#    'sooooooo': True,
#    'soooooooo': True,
#    'shattered': True,
#    'exam': True,
#    'hour': True,
#    'nooooooooooooooooooo': True,
#    'unprepared': True,
#    'usual': True},
#   'Negative'),
#  ({'sunday': True,
#    'usually': True,
#    'fun': True,
#    'prove': True,
#    'spending': True,
#    'mine': True,
#    'homework': True},
#   'Negative'),
#  ({'worst': True,
#    'part': True,
#    'baking': True,
#    'gift': True,
#    'cooky': True,
#    'eat': True},
#   'Negative'),
#  ({'sittin': True, 'apt': True, 'hungry': True}, 'Negative'),
#  ({'leuconoe': True,
#    'want': True,
#    'come': True,
#    'amp': True,
#    'visit': True,
#    'day': True,
#    'tuscany': True},
#   'Positive'),
#  ({'found': True,
#    'josh': True,
#    'game': True,
#    'morning': True,
#    'hv': True,
#    'class': True,
#    'boo': True,
#    'hoo': True},
#   'Negative'),
#  ({'melisie': True,
#    'hi': True,
#    'random': True,
#    'reply': True,
#    'fyi': True,
#    'think': True,
#    'awesome': True,
#    'idea': True,
#    'someone': True,
#    'get': True,
#    'top': True,
#    'stargirlinspace': True},
#   'Positive'),
#  ({'glennbeck': True,
#    'wish': True,
#    'could': True,
#    'come': True,
#    'see': True,
#    'u': True,
#    'denver': True,
#    'husband': True,
#    'lost': True,
#    'job': True,
#    'afford': True},
#   'Negative'),
#  ({'thehwicceman': True,
#    'happily': True,
#    'get': True,
#    'rid': True,
#    'see': True,
#    'radiohead': True,
#    'headline': True,
#    'nd': True,
#    'bill': True,
#    'better': True,
#    'nothing': True},
#   'Positive'),
#  ({'thegreenwelly': True,
#    'mmm': True,
#    'reffering': True,
#    'pink': True,
#    'whisky': True,
#    'bottle': True},
#   'Positive'),
#  ({'rmilana': True,
#    'good': True,
#    'least': True,
#    'bad': True,
#    'news': True,
#    'great': True,
#    'woke': True,
#    'long': True,
#    'ago': True,
#    'hi': True,
#    'lo': True,
#    'side': True,
#    'throw': True},
#   'Positive'),
#  ({'e': True,
#    'alot': True,
#    'better': True,
#    'last': True,
#    'year': True,
#    'time': True,
#    'study': True,
#    'less': True,
#    'gaming': True,
#    'pas': True,
#    'math': True,
#    'compass': True,
#    'exam': True},
#   'Negative'),
#  ({'missin': True,
#    'boy': True,
#    'rip': True,
#    'casey': True,
#    'amp': True,
#    'michael': True},
#   'Negative'),
#  ({'saurabh': True,
#    'ok': True,
#    'yes': True,
#    'infact': True,
#    'chatted': True,
#    'earlier': True,
#    'n': True,
#    'b': True,
#    'well': True},
#   'Positive'),
#  ({'cleveland': True, 'lost': True}, 'Negative'),
#  ({'heard': True,
#    'rumor': True,
#    'released': True,
#    'pdt': True,
#    'reliable': True,
#    'source': True},
#   'Negative'),
#  ({'went': True,
#    'new': True,
#    'indian': True,
#    'bar': True,
#    'grill': True,
#    'quot': True,
#    'mela': True,
#    'san': True,
#    'antonio': True,
#    'good': True,
#    'food': True,
#    'recession': True,
#    'price': True},
#   'Positive'),
#  ({'sinus': True,
#    'infection': True,
#    'damn': True,
#    'brother': True,
#    'anyways': True,
#    'night': True},
#   'Positive'),
#  ({'conkinho': True,
#    'think': True,
#    'possibly': True,
#    'better': True,
#    'badsex': True,
#    'lol': True,
#    'yeh': True,
#    'exactly': True,
#    'stil': True,
#    'shud': True,
#    'hav': True,
#    'sold': True,
#    'tho': True,
#    'oh': True,
#    'well': True},
#   'Negative'),
#  ({'work': True,
#    'love': True,
#    'working': True,
#    'saturday': True,
#    'everyone': True,
#    'happy': True},
#   'Positive'),
#  ({'saw': True,
#    'advert': True,
#    'attic': True,
#    'eden': True,
#    'tv': True,
#    'today': True,
#    'hmv': True,
#    'sure': True,
#    'pay': True,
#    'never': True,
#    'mind': True},
#   'Positive'),
#  ({'uh': True,
#    'computer': True,
#    'time': True,
#    'ahh': True,
#    'wanna': True,
#    'go': True,
#    'home': True,
#    'bad': True,
#    'last': True,
#    'wednesday': True,
#    'school': True,
#    'ever': True,
#    'reading': True,
#    'new': True,
#    'slam': True,
#    'zine': True,
#    'lt': True},
#   'Negative'),
#  ({'ruby': True,
#    'trying': True,
#    'nighter': True,
#    'dad': True,
#    'freaking': True,
#    'let': True,
#    'know': True,
#    'ok': True},
#   'Negative'),
#  ({'alive': True,
#    'seriously': True,
#    'thought': True,
#    'leslie': True,
#    'sansone': True,
#    'going': True,
#    'kill': True,
#    'quot': True,
#    'tummy': True,
#    'trimming': True,
#    'walk': True,
#    'whew': True},
#   'Positive'),
#  ({'want': True, 'fail': True, 'whale': True, 'shirt': True}, 'Positive'),
#  ({'panthergrrrl': True,
#    'yes': True,
#    'middlesbrough': True,
#    'today': True,
#    'gotta': True,
#    'business': True,
#    'enjoy': True,
#    'sunny': True,
#    'weekend': True},
#   'Positive'),
#  ({'go': True,
#    'watch': True,
#    'night': True,
#    'museum': True,
#    'wife': True,
#    'like': True,
#    'friday': True,
#    'date': True},
#   'Positive'),
#  ({'djblondeoso': True,
#    'thanks': True,
#    'right': True,
#    'til': True,
#    'next': True,
#    'time': True},
#   'Positive'),
#  ({'davidakimoto': True,
#    'hmmm': True,
#    'food': True,
#    'network': True,
#    'photowork': True,
#    'mga': True,
#    'toy': True,
#    'nothing': True,
#    'major': True,
#    'yet': True,
#    'tv': True,
#    'film': True,
#    'also': True},
#   'Positive'),
#  ({'blacksweater': True, 'nightmare': True}, 'Negative'),
#  ({'ash': True,
#    'nicole': True,
#    'ummm': True,
#    'wish': True,
#    'lol': True,
#    'mannnn': True,
#    'dis': True,
#    'shit': True,
#    'wack': True,
#    'n': True,
#    'way': True,
#    'makin': True,
#    'mil': True,
#    'one': True,
#    'nigga': True,
#    'give': True,
#    'dat': True},
#   'Negative'),
#  ({'wootshirt': True,
#    'last': True,
#    'shirt': True,
#    'gotten': True,
#    'get': True,
#    'tag': True,
#    'cut': True,
#    'due': True,
#    'extreme': True,
#    'itchyness': True,
#    'maybe': True,
#    'something': True,
#    'look': True},
#   'Negative'),
#  ({'carolinee': True}, 'Positive'),
#  ({'need': True, 'go': True, 'sleep': True}, 'Negative'),
#  ({'thelastdoctor': True, 'yes': True}, 'Positive'),
#  ({'jadennation': True,
#    'cooky': True,
#    'study': True,
#    'period': True,
#    'let': True,
#    'know': True},
#   'Positive'),
#  ({'im': True,
#    'done': True,
#    'bt': True,
#    'noy': True,
#    'sure': True,
#    'feelin': True,
#    'sleeepy': True,
#    'alah': True,
#    'eeen': True,
#    'bnaaaaaaaaaaaaaam': True},
#   'Negative'),
#  ({'tweet': True, 'lovin': True, 'tonight': True}, 'Negative'),
#  ({'iamjersey': True}, 'Negative'),
#  ({'clear': True, 'lake': True}, 'Negative'),
#  ({'andyroddick': True,
#    'unfortunatelly': True,
#    'saw': True,
#    'beginging': True,
#    'set': True,
#    'like': True,
#    'congrats': True},
#   'Positive'),
#  ({'mileycyrus': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'vt': True,
#    'cnt': True,
#    'believe': True,
#    'ur': True,
#    'age': True,
#    'lifesytle': True,
#    'wat': True,
#    'ppl': True,
#    'dream': True},
#   'Positive'),
#  ({'mobile': True,
#    'application': True,
#    'service': True,
#    'winning': True,
#    'new': True,
#    'client': True,
#    'dot': True,
#    'com': True,
#    'infoway': True,
#    'http': True,
#    'tinyurl': True,
#    'dllgdl': True},
#   'Positive'),
#  ({'dinosnail': True,
#    'morning': True,
#    'fun': True,
#    'love': True,
#    'gymnastics': True},
#   'Negative'),
#  ({'puka': True,
#    'shell': True,
#    'iya': True,
#    'maaf': True,
#    'banget': True,
#    'yaa': True,
#    'l': True,
#    'make': True},
#   'Positive'),
#  ({'propa': True,
#    'gandhi': True,
#    'awww': True,
#    'thanks': True,
#    'brad': True,
#    'hahaha': True,
#    'actually': True,
#    'made': True,
#    'laugh': True,
#    'loud': True,
#    'lbd': True},
#   'Positive'),
#  ({'fruitlatte': True,
#    'unfortunately': True,
#    'got': True,
#    'date': True,
#    'mixed': True,
#    'cannot': True,
#    'make': True},
#   'Negative'),
#  ({'oo': True, 'raining': True}, 'Negative'),
#  ({'lorrainestanick': True,
#    'macha': True,
#    'great': True,
#    'come': True,
#    'powder': True,
#    'u': True,
#    'put': True,
#    'drink': True,
#    'something': True,
#    'im': True,
#    'use': True,
#    'though': True},
#   'Positive'),
#  ({'bad': True, 'came': True, 'know': True, 'person': True, 'inside': True},
#   'Negative'),
#  ({'burger': True,
#    'jpg': True,
#    'shared': True,
#    'bayou': True,
#    'whaaaaaa': True,
#    'peut': True,
#    'etre': True,
#    'plus': True,
#    'gras': True,
#    'que': True,
#    'le': True,
#    'welsh': True,
#    'http': True,
#    'tinyurl': True,
#    'com': True,
#    'dg': True,
#    'um': True},
#   'Positive'),
#  ({'feel': True,
#    'like': True,
#    'nerd': True,
#    'today': True,
#    'haha': True,
#    'miss': True,
#    'everyone': True,
#    'home': True},
#   'Negative'),
#  ({'ashsimpsonwentz': True,
#    'wow': True,
#    'girl': True,
#    'pathetic': True,
#    'bad': True,
#    'give': True,
#    'fuck': True,
#    'right': True,
#    'haha': True,
#    'love': True,
#    'yew': True,
#    'ashley': True},
#   'Positive'),
#  ({'dana': True,
#    'quot': True,
#    'like': True,
#    'asian': True,
#    'version': True,
#    'mk': True,
#    'today': True,
#    'forgot': True,
#    'take': True,
#    'pic': True,
#    'blog': True,
#    'anyway': True,
#    'watching': True,
#    'double': True,
#    'jeopardy': True},
#   'Negative'),
#  ({'relaxin': True,
#    'sunday': True,
#    'watchin': True,
#    'movie': True,
#    'ali': True},
#   'Positive'),
#  ({'welcome': True,
#    'http': True,
#    'www': True,
#    'plurk': True,
#    'com': True,
#    'miahthegreat': True,
#    'miah': True,
#    'wooorld': True,
#    'party': True,
#    'p': True,
#    'wxdlg': True},
#   'Positive'),
#  ({'nabu': True, 'dew': True, 'cute': True}, 'Negative'),
#  ({'sooo': True, 'bored': True, 'hate': True, 'vacation': True}, 'Negative'),
#  ({'bemelicious': True, 'edie': True, 'longer': True, 'twitter': True},
#   'Negative'),
#  ({'kimmelinn': True,
#    'ashley': True,
#    'simpson': True,
#    'wow': True,
#    'good': True,
#    'make': True,
#    'easy': True,
#    'lol': True},
#   'Positive'),
#  ({'xkathyxrocksx': True,
#    'lucky': True,
#    'surprise': True,
#    'exam': True,
#    'today': True,
#    'revision': True,
#    'math': True,
#    'failed': True,
#    'test': True,
#    'one': True},
#   'Negative'),
#  ({'ashugreene': True}, 'Positive'),
#  ({'jksgirlx': True,
#    'spahkleprincess': True,
#    'word': True,
#    'hawt': True,
#    'dayum': True,
#    'oh': True,
#    'allowed': True,
#    'twittah': True,
#    'written': True,
#    'read': True,
#    'twice': True},
#   'Positive'),
#  ({'lesbridgets': True,
#    'com': True,
#    'seoadsenseman': True,
#    'gt': True,
#    'au': True,
#    'boulot': True,
#    'du': True,
#    'coup': True,
#    'courage': True},
#   'Positive'),
#  ({'pokemon': True,
#    'gold': True,
#    'amp': True,
#    'silver': True,
#    'vid': True,
#    'appeared': True,
#    'youtube': True,
#    'ystrday': True,
#    'afraid': True,
#    'busy': True,
#    'think': True,
#    'idea': True,
#    'coursework': True,
#    'finished': True,
#    'tho': True},
#   'Positive'),
#  ({'jimmytoriola': True,
#    'cant': True,
#    'type': True,
#    'much': True,
#    'lol': True,
#    'say': True,
#    'interesting': True,
#    'time': True,
#    'gotta': True,
#    'love': True},
#   'Positive'),
#  ({'note': True,
#    'self': True,
#    'beware': True,
#    'freezer': True,
#    'door': True,
#    'big': True,
#    'boo': True},
#   'Negative'),
#  ({'bought': True,
#    'two': True,
#    'new': True,
#    'short': True,
#    'aeropostale': True},
#   'Positive'),
#  ({'place': True, 'dream': True, 'maybe': True, 'see': True, 'sweet': True},
#   'Positive'),
#  ({'ohbribri': True,
#    'nite': True,
#    'put': True,
#    'prince': True,
#    'track': True,
#    'amp': True,
#    'sweet': True,
#    'dream': True},
#   'Positive'),
#  ({'hoffmanrobert': True, 'r': True, 'u': True}, 'Positive'),
#  ({'caarolcarvalho': True,
#    'true': True,
#    'friend': True,
#    'someone': True,
#    'think': True,
#    'good': True,
#    'egg': True,
#    'even': True,
#    'though': True,
#    'know': True,
#    'slightly': True,
#    'cracked': True,
#    'made': True,
#    'ya': True},
#   'Positive'),
#  ({'misssabrinasin': True,
#    'wow': True,
#    'fun': True,
#    'haha': True,
#    'life': True,
#    'working': True,
#    'girl': True},
#   'Negative'),
#  ({'working': True, 'home': True, 'sick': True, 'girl': True}, 'Negative'),
#  ({'babeqirl': True,
#    'lol': True,
#    'yeah': True,
#    'ill': True,
#    'tell': True,
#    'later': True,
#    'lmao': True},
#   'Positive'),
#  ({'lilicosic': True, 'hehe': True, 'thanks': True}, 'Positive'),
#  ({'pattib': True,
#    'omfg': True,
#    'going': True,
#    'see': True,
#    'britney': True,
#    'spear': True,
#    'australia': True,
#    'soo': True,
#    'jealous': True},
#   'Negative'),
#  ({'well': True,
#    'im': True,
#    'tired': True,
#    'ok': True,
#    'w': True,
#    'e': True,
#    'skint': True,
#    'aw': True,
#    'rubbish': True,
#    'weekend': True,
#    'good': True,
#    'dunbarr': True},
#   'Negative'),
#  ({'great': True,
#    'night': True,
#    'playing': True,
#    'catch': True,
#    'phrase': True,
#    'hunt': True,
#    'law': True,
#    'hanging': True,
#    'around': True,
#    'house': True},
#   'Positive'),
#  ({'susan': True, 'boyle': True, 'great': True, 'singer': True}, 'Negative'),
#  ({'chrismusick': True, 'work': True, 'still': True, 'got': True, 'em': True},
#   'Negative'),
#  ({'mysticmedusa': True,
#    'rudd': True,
#    'keep': True,
#    'offline': True,
#    'hence': True,
#    'surprise': True,
#    'virgo': True,
#    'kloset': True,
#    'kinksters': True,
#    'sun': True,
#    'virg': True,
#    'bit': True},
#   'Positive'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'iq': True,
#    'remote': True,
#    'control': True,
#    'lower': True,
#    'hahaha': True,
#    'srsly': True},
#   'Negative'),
#  ({'juilliard': True, 'goodluck': True, 'chemistry': True}, 'Positive'),
#  ({'gmail': True, 'locked': True}, 'Negative'),
#  ({'coco': True,
#    'sick': True,
#    'get': True,
#    'better': True,
#    'baby': True,
#    'work': True},
#   'Negative'),
#  ({'owww': True, 'hit': True, 'hand': True, 'corner': True, 'laptop': True},
#   'Negative'),
#  ({'rise': True,
#    'shine': True,
#    'going': True,
#    'car': True,
#    'shopping': True,
#    'pop': True},
#   'Positive'),
#  ({'apolloschild': True, 'bad': True, 'go': True}, 'Negative'),
#  ({'mennard': True,
#    'oh': True,
#    'sorry': True,
#    'social': True,
#    'medium': True,
#    'cafe': True,
#    'manchester': True,
#    'http': True,
#    'socialmediacafemanchester': True,
#    'pbworks': True,
#    'com': True,
#    'wd': True,
#    'nice': True,
#    'meet': True,
#    'person': True},
#   'Positive'),
#  ({'tommcfly': True,
#    'hey': True,
#    'u': True,
#    'take': True,
#    'flying': True,
#    'whenever': True,
#    'want': True,
#    'waiting': True,
#    'tom': True,
#    'hahaha': True,
#    'luv': True,
#    'ya': True},
#   'Positive'),
#  ({'seancallanan': True,
#    'wanna': True,
#    'get': True,
#    'kevinruddmp': True,
#    'think': True,
#    'kev': True,
#    'tweetupmellers': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'wacjl': True},
#   'Positive'),
#  ({'keropop': True,
#    'getting': True,
#    'week': True,
#    'dx': True,
#    'get': True,
#    'anymore': True,
#    'attached': True,
#    'cockroach': True,
#    'decide': True,
#    'keep': True,
#    'pet': True},
#   'Positive'),
#  ({'need': True, 'stop': True, 'procrastinator': True, 'help': True},
#   'Negative'),
#  ({'herojaejoong': True,
#    'oppa': True,
#    'someday': True,
#    'stop': True,
#    'feeling': True,
#    'may': True,
#    'run': True,
#    'enven': True,
#    'though': True,
#    'see': True,
#    'u': True,
#    'far': True,
#    'really': True,
#    'love': True},
#   'Negative'),
#  ({'kitten': True, 'ran': True, 'away': True}, 'Negative'),
#  ({'henry': True, 'waiting': True, 'go': True, 'breakfast': True}, 'Positive'),
#  ({'rainy': True, 'wednesday': True}, 'Negative'),
#  ({'cooking': True, 'loving': True, 'every': True, 'second': True},
#   'Positive'),
#  ({'happy': True,
#    'mother': True,
#    'day': True,
#    'oh': True,
#    'love': True,
#    'mom': True,
#    'hehehe': True},
#   'Positive'),
#  ({'bella': True,
#    'need': True,
#    'sit': True,
#    'long': True,
#    'u': True,
#    'wiggle': True,
#    'dance': True,
#    'lol': True},
#   'Positive'),
#  ({'cant': True, 'find': True, 'f': True, 'friend': True, 'twitter': True},
#   'Negative'),
#  ({'hurray': True, 'old': True, 'friend': True, 'beer': True, 'lady': True},
#   'Positive'),
#  ({'poisonandfire': True,
#    'cavalier': True,
#    'many': True,
#    'syllable': True,
#    'cavs': True,
#    'much': True,
#    'easier': True,
#    'say': True,
#    'fun': True,
#    'chant': True},
#   'Positive'),
#  ({'wossy': True,
#    'watching': True,
#    'yr': True,
#    'show': True,
#    'friday': True,
#    'excellent': True,
#    'usual': True,
#    'amp': True,
#    'gorgeous': True,
#    'ewan': True,
#    'mcgregor': True,
#    'could': True,
#    'watch': True,
#    'listen': True,
#    'day': True,
#    'night': True},
#   'Positive'),
#  ({'skater': True,
#    'good': True,
#    'thank': True,
#    'yes': True,
#    'night': True,
#    'hehe': True},
#   'Positive'),
#  ({'know': True, 'going': True, 'let': True, 'good': True, 'night': True},
#   'Positive'),
#  ({'jo': True,
#    'whit': True,
#    'hi': True,
#    'sweetie': True,
#    'bye': True,
#    'dinns': True,
#    'x': True},
#   'Positive'),
#  ({'archie': True,
#    'getting': True,
#    'married': True,
#    'veronica': True,
#    'congratulation': True,
#    'betty': True,
#    'must': True,
#    'soooooooo': True,
#    'disappointed': True,
#    'waited': True,
#    'year': True},
#   'Positive'),
#  ({'saved': True,
#    'grocery': True,
#    'biill': True,
#    'today': True,
#    'love': True,
#    'coupon': True,
#    'especially': True,
#    'thegrocerygame': True,
#    'com': True},
#   'Positive'),
#  ({'jmac': True, 'lol': True, 'u': True, 'know': True, 'got': True},
#   'Positive'),
#  ({'reaching': True, 'star': True, 'hug': True}, 'Negative'),
#  ({'boo': True, 'naw': True, 'really': True}, 'Negative'),
#  ({'jennytablina': True,
#    'know': True,
#    'least': True,
#    'people': True,
#    'seem': True,
#    'literally': True,
#    'lost': True,
#    'mind': True},
#   'Negative'),
#  ({'today': True,
#    'weird': True,
#    'meeting': True,
#    'got': True,
#    'postponed': True,
#    'outluk': True,
#    'screwd': True,
#    'terribly': True,
#    'hot': True,
#    'outside': True,
#    'n': True,
#    'getting': True,
#    'irritated': True,
#    'need': True,
#    'punchin': True,
#    'bag': True},
#   'Negative'),
#  ({'djkiezo': True, 'aw': True, 'getting': True}, 'Negative'),
#  ({'fine': True, 'car': True, 'much': True}, 'Negative'),
#  ({'djtlac': True, 'fuck': True}, 'Negative'),
#  ({'girlpie': True,
#    'hi': True,
#    'nice': True,
#    'meet': True,
#    'see': True,
#    'suffer': True,
#    'agoraphobia': True,
#    'well': True,
#    'hope': True,
#    'fine': True,
#    'take': True,
#    'care': True},
#   'Positive'),
#  ({'enjoy': True,
#    'sunny': True,
#    'day': True,
#    'without': True,
#    'rainy': True,
#    'dane': True,
#    'cook': True,
#    'rest': True,
#    'isolated': True,
#    'incident': True,
#    'amp': True,
#    'crashingg': True},
#   'Positive'),
#  ({'johnfleischauer': True, 'see': True, 'suprise': True}, 'Positive'),
#  ({'joelmadden': True,
#    'long': True,
#    'take': True,
#    'learn': True,
#    'song': True},
#   'Positive'),
#  ({'spotibot': True,
#    'afraid': True,
#    'bit': True,
#    'fail': True,
#    'last': True,
#    'two': True,
#    'recommendation': True,
#    'available': True,
#    'uk': True},
#   'Negative'),
#  ({'gailporter': True,
#    'flower': True,
#    'usually': True,
#    'bloom': True,
#    'summer': True},
#   'Positive'),
#  ({'deathangel': True, 'yup': True, 'else': True, 'say': True, 'lolz': True},
#   'Positive'),
#  ({'head': True, 'hurt': True, 'one': True, 'wanted': True, 'robinson': True},
#   'Negative'),
#  ({'oh': True,
#    'hello': True,
#    'second': True,
#    'weekend': True,
#    'brewing': True,
#    'iced': True,
#    'tea': True,
#    'settling': True,
#    'day': True,
#    'rawrz': True},
#   'Positive'),
#  ({'isplayer': True, 'died': True, 'sorry': True}, 'Negative'),
#  ({'puppy': True, 'ill': True}, 'Negative'),
#  ({'loner': True, 'tonight': True}, 'Negative'),
#  ({'holy': True, 'crap': True, 'achey': True}, 'Negative'),
#  ({'really': True,
#    'seperate': True,
#    'tweet': True,
#    'deck': True,
#    'group': True},
#   'Negative'),
#  ({'somecitygirl': True, 'hahahaha': True, 'ok': True, 'sry': True},
#   'Negative'),
#  ({'hugely': True,
#    'disappointed': True,
#    'getting': True,
#    'meet': True,
#    'great': True,
#    'genesis': True,
#    'p': True,
#    'orridge': True,
#    'throbbing': True,
#    'gristle': True,
#    'glasgow': True,
#    'gig': True,
#    'tonight': True},
#   'Negative'),
#  ({'gloom': True, 'shadow': True}, 'Negative'),
#  ({'watching': True, 'nanny': True, 'trying': True, 'go': True, 'sleep': True},
#   'Positive'),
#  ({'heatherwhatever': True,
#    'oh': True,
#    'didnt': True,
#    'poor': True,
#    'hair': True,
#    'haha': True},
#   'Negative'),
#  ({'drmommy': True, 'got': True, 'smile': True}, 'Positive'),
#  ({'bout': True, 'fall': True, 'asleep': True, 'good': True, 'night': True},
#   'Positive'),
#  ({'txt': True, 'message': True, 'justin': True, 'make': True, 'happy': True},
#   'Positive'),
#  ({'finished': True,
#    'best': True,
#    'dinner': True,
#    'brown': True,
#    'rice': True,
#    'fake': True,
#    'ch': True,
#    'ckn': True,
#    'teryaki': True,
#    'gonna': True,
#    'pretend': True,
#    'healthy': True},
#   'Positive'),
#  ({'cellarrats': True,
#    'oh': True,
#    'yeah': True,
#    'got': True,
#    'request': True,
#    'day': True,
#    'gooooood': True},
#   'Positive'),
#  ({'got': True,
#    'back': True,
#    'shopping': True,
#    'tonight': True,
#    'second': True,
#    'last': True,
#    'day': True,
#    'dance': True,
#    'season': True,
#    'sad': True,
#    'recital': True,
#    'sunday': True},
#   'Negative'),
#  ({'congrats': True,
#    'supricky': True,
#    'making': True,
#    'news': True,
#    'video': True,
#    'dothetwitterdance': True},
#   'Positive'),
#  ({'worship': True,
#    'house': True,
#    'md': True,
#    'swear': True,
#    'freak': True,
#    'see': True,
#    'anyone': True,
#    'wearing': True,
#    'white': True,
#    'coat': True,
#    'patient': True},
#   'Negative'),
#  ({'omjchristinaaa': True, 'awwwwe': True, 'wish': True}, 'Negative'),
#  ({'goood': True,
#    'night': True,
#    'gonnaaa': True,
#    'watch': True,
#    'office': True,
#    'tonite': True},
#   'Positive'),
#  ({'jdavidclarke': True,
#    'twitter': True,
#    'like': True,
#    'personal': True,
#    'problem': True,
#    'ticket': True,
#    'system': True,
#    'go': True,
#    'habs': True,
#    'kidding': True},
#   'Positive'),
#  ({'denied': True,
#    'entry': True,
#    'siddhivinaayak': True,
#    'temple': True,
#    'thanks': True,
#    'laptop': True},
#   'Negative'),
#  ({'waiting': True,
#    'list': True,
#    'starting': True,
#    'get': True,
#    'longer': True,
#    'could': True,
#    'finding': True,
#    'new': True,
#    'home': True},
#   'Negative'),
#  ({'already': True}, 'Negative'),
#  ({'donniewahlberg': True,
#    'whoohoo': True,
#    'great': True,
#    'time': True,
#    'tonight': True},
#   'Positive'),
#  ({'nokia': True, 'died': True}, 'Negative'),
#  ({'goodnight': True,
#    'everyone': True,
#    'hope': True,
#    'jonas': True,
#    'brother': True,
#    'come': True,
#    'back': True,
#    'l': True,
#    'already': True},
#   'Negative'),
#  ({'toothache': True, 'migraine': True}, 'Negative'),
#  ({'awake': True,
#    'going': True,
#    'work': True,
#    'nursery': True,
#    'bit': True,
#    'today': True,
#    'wish': True,
#    'ikea': True,
#    'nb': True},
#   'Negative'),
#  ({'modernpest': True, 'monday': True}, 'Negative'),
#  ({'ellimist': True, 'knitted': True, 'sweater': True, 'dork': True},
#   'Positive'),
#  ({'lannaa': True,
#    'im': True,
#    'sorrry': True,
#    'need': True,
#    'go': True,
#    'soon': True,
#    'btw': True,
#    'thinking': True,
#    'tb': True,
#    'deffinately': True,
#    'money': True},
#   'Negative'),
#  ({'markwhiting': True,
#    'sure': True,
#    'yet': True,
#    'apparently': True,
#    'guess': True,
#    'attendee': True,
#    'clue': True,
#    'twitter': True,
#    'argument': True,
#    'kn': True},
#   'Negative'),
#  ({'mr': True, 'bill': True, 'good': True, 'morning': True}, 'Positive'),
#  ({'danny': True,
#    'rage': True,
#    'ear': True,
#    'hear': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'q': True,
#    'wj': True},
#   'Negative'),
#  ({'futuresocialite': True,
#    'lost': True,
#    'want': True,
#    'old': True,
#    'phone': True,
#    'back': True},
#   'Negative'),
#  ({'woke': True,
#    'voice': True,
#    'amp': True,
#    'desperately': True,
#    'wanting': True,
#    'die': True,
#    'nyquil': True,
#    'bedrest': True,
#    'new': True,
#    'bff': True},
#   'Negative'),
#  ({'alyahs': True, 'get': True, 'email': True}, 'Negative'),
#  ({'fischi': True,
#    'dont': True,
#    'rightly': True,
#    'know': True,
#    'meet': True,
#    'tday': True},
#   'Negative'),
#  ({'pinging': True,
#    'mzkane': True,
#    'n': True,
#    'baby': True,
#    'sorry': True,
#    'ppl': True,
#    'rushing': True,
#    'forgot': True,
#    'pic': True,
#    'awwwwwwww': True,
#    'sucker': True,
#    'love': True,
#    'good': True},
#   'Positive'),
#  ({'thanks': True,
#    'someecards': True,
#    'letting': True,
#    'know': True,
#    'teacher': True,
#    'week': True,
#    'start': True,
#    'today': True,
#    'hopefully': True,
#    'end': True,
#    'quot': True,
#    'officially': True},
#   'Positive'),
#  ({'sezykins': True, 'good': True, 'evening': True, 'day': True}, 'Positive'),
#  ({'homework': True,
#    'day': True,
#    'mom': True,
#    'amp': True,
#    'brother': True,
#    'soon': True},
#   'Negative'),
#  ({'sarahmerion': True,
#    'like': True,
#    'quote': True,
#    'alot': True,
#    'keep': True,
#    'mind': True,
#    'next': True,
#    'time': True,
#    'enter': True,
#    'room': True,
#    'hope': True,
#    'good': True,
#    'saturday': True},
#   'Positive'),
#  ({'googlygoogly': True, 'fucking': True, 'problem': True}, 'Negative'),
#  ({'going': True,
#    'naked': True,
#    'cuddle': True,
#    'erik': True,
#    'amp': True,
#    'watch': True,
#    'office': True,
#    'pas': True,
#    'giving': True,
#    'sponge': True,
#    'bath': True,
#    'post': True,
#    'op': True,
#    'tomorrow': True},
#   'Positive'),
#  ({'remember': True,
#    'accident': True,
#    'truck': True,
#    'ploughed': True,
#    'tripled': True,
#    'insurance': True,
#    'settled': True,
#    'still': True,
#    'double': True},
#   'Negative'),
#  ({'deppelchen': True, 'going': True, 'away': True}, 'Negative'),
#  ({'charlesgokey': True,
#    'yummmm': True,
#    'salad': True,
#    'dressing': True,
#    'side': True},
#   'Negative'),
#  ({'misspear': True,
#    'always': True,
#    'thought': True,
#    'trampette': True,
#    'female': True,
#    'tramp': True,
#    'stop': True,
#    'putting': True,
#    'one': True,
#    'bungalow': True,
#    'though': True},
#   'Positive'),
#  ({'fot': True, 'got': True, 'fork': True}, 'Negative'),
#  ({'tiredd': True, 'nothing': True, 'today': True}, 'Negative'),
#  ({'softthistle': True,
#    'damn': True,
#    'bit': True,
#    'give': True,
#    'something': True,
#    'look': True,
#    'forward': True,
#    'guess': True},
#   'Negative'),
#  ({'one': True,
#    'day': True,
#    'desperate': True,
#    'need': True,
#    'cheering': True,
#    'taker': True,
#    'lol': True},
#   'Negative'),
#  ({'dianarusso': True, 'got': True, 'dm': True}, 'Positive'),
#  ({'seasonsays': True,
#    'head': True,
#    'jc': True,
#    'basketball': True,
#    'game': True,
#    'embarrass': True,
#    'nobody': True,
#    'even': True,
#    'brother': True,
#    'would': True,
#    'kick': True,
#    'azz': True},
#   'Negative'),
#  ({'uuuuuuuugh': True,
#    'soooo': True,
#    'tired': True,
#    'hate': True,
#    'train': True,
#    'much': True,
#    'especially': True,
#    'there': True,
#    'big': True,
#    'fail': True,
#    'seat': True,
#    'place': True,
#    'though': True,
#    'start': True,
#    'new': True,
#    'song': True},
#   'Negative'),
#  ({'let': True,
#    'see': True,
#    'tomorrow': True,
#    'brings': True,
#    'superrrr': True,
#    'awake': True,
#    'lol': True},
#   'Positive'),
#  ({'lemongeneration': True,
#    'heart': True,
#    'sorry': True,
#    'type': True,
#    'tweetdeck': True},
#   'Negative'),
#  ({'nooooo': True, 'youtube': True, 'sad': True}, 'Negative'),
#  ({'sleep': True, 'study': True, 'exam': True, 'chemistry': True}, 'Negative'),
#  ({'lilinator': True,
#    'hullo': True,
#    'rain': True,
#    'least': True,
#    'limerick': True,
#    'subverted': True,
#    'tone': True,
#    'nuanced': True,
#    'ear': True,
#    'hear': True},
#   'Positive'),
#  ({'missed': True, 'fun': True}, 'Negative'),
#  ({'good': True,
#    'night': True,
#    'everyone': True,
#    'need': True,
#    'sleep': True,
#    'one': True,
#    'wherever': True},
#   'Positive'),
#  ({'annericeauthor': True,
#    'absolutely': True,
#    'make': True,
#    'cry': True,
#    'hope': True,
#    'son': True,
#    'get': True,
#    'older': True,
#    'peace': True,
#    'human': True,
#    'right': True,
#    'laid': True},
#   'Negative'),
#  ({'sad': True,
#    'kristin': True,
#    'cavallari': True,
#    'bring': True,
#    'hill': True,
#    'instead': True,
#    'lauren': True,
#    'conrad': True},
#   'Negative'),
#  ({'brother': True,
#    'girlfriend': True,
#    'coming': True,
#    'home': True,
#    'next': True,
#    'week': True,
#    'seen': True,
#    'since': True,
#    'december': True,
#    'oh': True,
#    'miss': True,
#    'sooo': True,
#    'much': True,
#    'lt': True},
#   'Negative'),
#  ({'playing': True,
#    'basketball': True,
#    'today': True,
#    'homework': True,
#    'free': True,
#    'court': True},
#   'Negative'),
#  ({'jonasbrothers': True,
#    'right': True,
#    'song': True,
#    'quot': True,
#    'see': True,
#    'amazing': True,
#    'listening': True,
#    'time': True},
#   'Positive'),
#  ({'pauldawsonsr': True,
#    'im': True,
#    'already': True,
#    'following': True,
#    'markvhansen': True,
#    'checked': True,
#    'thx': True,
#    'bro': True,
#    'hug': True,
#    'ya': True},
#   'Positive'),
#  ({'amazed': True,
#    'see': True,
#    'potato': True,
#    'content': True,
#    'pringles': True,
#    'http': True,
#    'news': True,
#    'bbc': True,
#    'co': True,
#    'uk': True,
#    'hi': True,
#    'business': True,
#    'stm': True,
#    'via': True,
#    'matheussiq': True},
#   'Positive'),
#  ({'watching': True,
#    'disney': True,
#    'channel': True,
#    'eating': True,
#    'breackfast': True},
#   'Positive'),
#  ({'ed': True, 'got': True, 'fired': True, 'scrub': True, 'swa': True},
#   'Negative'),
#  ({'madamearkadina': True, 'know': True, 'feeling': True}, 'Positive'),
#  ({'cool': True,
#    'lol': True,
#    'better': True,
#    'double': True,
#    'checkin': True,
#    'reminder': True,
#    'bday': True,
#    'day': True},
#   'Positive'),
#  ({'father': True,
#    'day': True,
#    'hmmm': True,
#    'best': True,
#    'fall': True,
#    'friend': True,
#    'dnt': True,
#    'even': True,
#    'talk': True,
#    'dad': True,
#    'anyway': True,
#    'gr': True},
#   'Negative'),
#  ({'frogpond': True, 'glad': True, 'enjoyed': True}, 'Positive'),
#  ({'watched': True,
#    'american': True,
#    'idol': True,
#    'jordin': True,
#    'great': True,
#    'also': True,
#    'katy': True,
#    'sexy': True,
#    'goodbye': True,
#    'danny': True,
#    'adam': True,
#    'amp': True,
#    'kris': True,
#    'goodluck': True},
#   'Positive'),
#  ({'childhood': True,
#    'knitting': True,
#    'playgroup': True,
#    'missed': True,
#    'chick': True,
#    'show': True,
#    'listen': True,
#    'demand': True},
#   'Negative'),
#  ({'kusasi': True,
#    'prepare': True,
#    'cake': True,
#    'planning': True,
#    'weekend': True,
#    'hope': True,
#    'come': True,
#    'watch': True},
#   'Positive'),
#  ({'amazing': True, 'get': True, 'sad': True, 'second': True}, 'Negative'),
#  ({'tip': True,
#    'never': True,
#    'get': True,
#    'stuck': True,
#    'shed': True,
#    'thunderstorm': True,
#    'rabbit': True,
#    'thats': True,
#    'heard': True,
#    'thunder': True,
#    'result': True,
#    'lot': True,
#    'blood': True},
#   'Negative'),
#  ({'technotetris': True, 'going': True, 'beach': True}, 'Positive'),
#  ({'dammit': True,
#    'plugged': True,
#    'ipod': True,
#    'got': True,
#    'wiped': True,
#    'clean': True},
#   'Negative'),
#  ({'hurray': True, 'roommate': True, 'busting': True, 'crib': True},
#   'Positive'),
#  ({'strandsofpearls': True,
#    'good': True,
#    'hate': True,
#    'big': True,
#    'refresh': True,
#    'button': True,
#    'tweetie': True,
#    'amp': True,
#    'like': True,
#    'twitterfon': True,
# ...
#    'maintenance': True},
#   'Positive'),
#  ({'p': True,
#    'sharing': True,
#    'great': True,
#    'little': True,
#    'setting': True,
#    'want': True,
#    'get': True,
#    'crowded': True},
#   'Positive'),
#  ({'sitting': True, 'home': True, 'art': True}, 'Positive'),
#  ({'miss': True, 'friend': True}, 'Negative'),
#  ({'johnlacey': True,
#    'damn': True,
#    'secretly': True,
#    'love': True,
#    'stay': True,
#    'stuck': True,
#    'head': True},
#   'Positive'),
#  ({'mklaebel': True, 'morning': True}, 'Positive'),
#  ({'hilsofhove': True,
#    'yes': True,
#    'saw': True,
#    'lovely': True,
#    'always': True,
#    'wanted': True,
#    'donkey': True,
#    'brought': True,
#    'farm': True,
#    'kept': True,
#    'asking': True,
#    'one': True,
#    'never': True,
#    'happened': True},
#   'Negative'),
#  ({'finally': True, 'home': True, 'work': True, 'soon': True}, 'Negative'),
#  ({'mnstrsnmnchkns': True,
#    'lol': True,
#    'hello': True,
#    'quite': True,
#    'difficult': True,
#    'meeting': True,
#    'someone': True,
#    'alive': True,
#    'heterosexual': True,
#    'single': True,
#    'know': True},
#   'Positive'),
#  ({'sianz': True,
#    'mmm': True,
#    'took': True,
#    'couple': True,
#    'doubt': True,
#    'hit': True,
#    'flickr': True,
#    'account': True,
#    'later': True,
#    'tonight': True},
#   'Positive'),
#  ({'whipping': True, 'bunch': True, 'frownies': True}, 'Negative'),
#  ({'cuddled': True, 'cousin': True, 'kim': True}, 'Positive'),
#  ({'yum': True, 'really': True, 'want': True, 'oporto': True}, 'Negative'),
#  ({'lark': True,
#    'vamp': True,
#    'hug': True,
#    'poblem': True,
#    'like': True,
#    'said': True,
#    'least': True,
#    'could': True},
#   'Positive'),
#  ({'leave': True,
#    'twitter': True,
#    'alone': True,
#    'night': True,
#    'last': True,
#    'barcelona': True,
#    'back': True,
#    'philly': True,
#    'tomorrow': True,
#    'hope': True,
#    'u': True,
#    'great': True,
#    'friday': True,
#    'muahh': True},
#   'Negative'),
#  ({'purplepyropixie': True,
#    'within': True,
#    'minute': True,
#    'previous': True,
#    'post': True,
#    'sun': True,
#    'disappeared': True,
#    'huuuuuuge': True,
#    'black': True,
#    'cloud': True},
#   'Negative'),
#  ({'painkiller': True,
#    'becoming': True,
#    'less': True,
#    'effective': True,
#    'even': True,
#    'though': True,
#    'think': True,
#    'system': True,
#    'awesome': True,
#    'neverwas': True},
#   'Negative'),
#  ({'oooooouuuuuuuuuucccccccchhhh': True,
#    'pin': True,
#    'needle': True,
#    'foot': True},
#   'Negative'),
#  ({'indielette': True, 'seems': True, 'working': True, 'today': True},
#   'Positive'),
#  ({'school': True, 'english': True, 'right': True}, 'Positive'),
#  ({'got': True, 'home': True, 'fun': True, 'evening': True, 'sizzies': True},
#   'Positive'),
#  ({'chilling': True,
#    'day': True,
#    'lol': True,
#    'listening': True,
#    'pink': True,
#    'gcse': True,
#    'math': True,
#    'wish': True,
#    'best': True,
#    'luck': True,
#    'xx': True},
#   'Positive'),
#  ({'muffinac': True, 'sweetie': True, 'talked': True, 'forever': True},
#   'Negative'),
#  ({'stupid': True,
#    'cocking': True,
#    'megavideo': True,
#    'wish': True,
#    'wixi': True,
#    'wasnt': True,
#    'today': True},
#   'Negative'),
#  ({'munchkiss': True,
#    'nah': True,
#    'juz': True,
#    'really': True,
#    'slow': True,
#    'day': True},
#   'Negative'),
#  ({'moisesarias': True,
#    'moises': True,
#    'heyyy': True,
#    'lt': True,
#    'whatss': True,
#    'upp': True},
#   'Positive'),
#  ({'greggarbo': True, 'absolutely': True, 'amazing': True}, 'Positive'),
#  ({'qettin': True,
#    'da': True,
#    'shower': True,
#    'without': True,
#    'xraytid': True,
#    'kuz': True,
#    'hurt': True,
#    'feelinqz': True},
#   'Negative'),
#  ({'betsy': True,
#    'ooo': True,
#    'whats': True,
#    'name': True,
#    'mine': True,
#    'daniwilson': True},
#   'Positive'),
#  ({'supposed': True,
#    'see': True,
#    'hangover': True,
#    'today': True,
#    'guess': True,
#    'gonna': True,
#    'wait': True,
#    'till': True,
#    'tuesday': True},
#   'Negative'),
#  ({'radchick': True, 'hi': True}, 'Positive'),
#  ({'marlissadessy': True, 'kind': True, 'surgery': True}, 'Positive'),
#  ({'damonford': True,
#    'start': True,
#    'draft': True,
#    'new': True,
#    'word': True,
#    'file': True,
#    'save': True,
#    'old': True,
#    'one': True,
#    'altho': True,
#    'chapter': True,
#    'pretty': True,
#    'bad': True,
#    'heh': True},
#   'Positive'),
#  ({'since': True,
#    'slept': True,
#    'ok': True,
#    'zoe': True,
#    'lil': True,
#    'whiney': True,
#    'lot': True,
#    'day': True},
#   'Negative'),
#  ({'portillo': True, 'anybody': True, 'eat': True, 'apply': True, 'job': True},
#   'Positive'),
#  ({'power': True,
#    'outage': True,
#    'heard': True,
#    'siren': True,
#    'outside': True,
#    'probably': True,
#    'good': True,
#    'day': True,
#    'someone': True},
#   'Negative'),
#  ({'cornwall': True,
#    'info': True,
#    'indeed': True,
#    'know': True,
#    'much': True,
#    'rather': True,
#    'competition': True,
#    'really': True,
#    'roll': True,
#    'october': True,
#    'next': True,
#    'visit': True},
#   'Positive'),
#  ({'im': True, 'glad': True, 'figured': True, 'twitter': True}, 'Positive'),
#  ({'jasonmawdsley': True,
#    'called': True,
#    'monitoring': True,
#    'tool': True,
#    'technology': True,
#    'include': True,
#    'asp': True,
#    'net': True,
#    'flex': True,
#    'happy': True,
#    'way': True,
#    'pm': True,
#    'amp': True,
#    'pls': True},
#   'Positive'),
#  ({'feeling': True,
#    'little': True,
#    'sleepy': True,
#    'excited': True,
#    'get': True,
#    'see': True,
#    'emilio': True,
#    'minute': True},
#   'Positive'),
#  ({'found': True,
#    'might': True,
#    'rain': True,
#    'june': True,
#    'th': True,
#    'still': True,
#    'wearing': True,
#    'shirt': True,
#    'skirt': True,
#    'hoody': True},
#   'Negative'),
#  ({'sooo': True,
#    'min': True,
#    'till': True,
#    'eat': True,
#    'drink': True,
#    'anything': True,
#    'surgery': True,
#    'bring': True,
#    'candy': True},
#   'Positive'),
#  ({'extorian': True,
#    'ff': True,
#    'man': True,
#    'ie': True,
#    'amp': True,
#    'perfectly': True,
#    'acceptable': True,
#    'though': True,
#    'use': True,
#    'cause': True,
#    'much': True,
#    'work': True},
#   'Negative'),
#  ({'broke': True, 'two': True, 'bone': True, 'nose': True}, 'Negative'),
#  ({'nuishow': True, 'recovering': True, 'krub': True}, 'Positive'),
#  ({'dannieboytv': True,
#    'knoww': True,
#    'like': True,
#    'mannn': True,
#    'lolll': True,
#    'bruno': True},
#   'Negative'),
#  ({'gonna': True, 'watch': True, 'icarly': True}, 'Positive'),
#  ({'loic': True,
#    'tweet': True,
#    'show': True,
#    'scoble': True,
#    'right': True,
#    'path': True,
#    'karaswisher': True,
#    'fbook': True,
#    'connect': True,
#    'disqus': True,
#    'googleconnect': True},
#   'Negative'),
#  ({'gonna': True, 'another': True, 'pet': True, 'name': True, 'bolt': True},
#   'Positive'),
#  ({'sitting': True,
#    'traffic': True,
#    'car': True,
#    'get': True,
#    'rained': True,
#    'washed': True,
#    'sunday': True,
#    'weather': True,
#    'know': True,
#    'california': True},
#   'Negative'),
#  ({'starving': True, 'nothing': True, 'want': True, 'eat': True}, 'Negative'),
#  ({'strangely': True,
#    'enough': True,
#    'getting': True,
#    'k': True,
#    'yesterday': True,
#    'made': True,
#    'positive': True,
#    'carpe': True,
#    'diem': True,
#    'etc': True},
#   'Positive'),
#  ({'risktical': True,
#    'looked': True,
#    'service': True,
#    'provider': True,
#    'level': True,
#    'change': True,
#    'yet': True,
#    'sp': True,
#    'assessed': True},
#   'Negative'),
#  ({'watching': True, 'da': True, 'vinci': True, 'code': True}, 'Positive'),
#  ({'fuchsiastiletto': True,
#    'yes': True,
#    'wicked': True,
#    'w': True,
#    'end': True,
#    'far': True,
#    'much': True,
#    'alcohol': True},
#   'Positive'),
#  ({'random': True,
#    'tired': True,
#    'need': True,
#    'learn': True,
#    'sleep': True,
#    'earlier': True,
#    'http': True,
#    'tumblr': True,
#    'com': True,
#    'xvq': True,
#    'xbh': True},
#   'Negative'),
#  ({'best': True, 'mood': True, 'today': True}, 'Negative'),
#  ({'anant': True,
#    'unfair': True,
#    'good': True,
#    'rock': True,
#    'show': True,
#    'happen': True,
#    'b': True,
#    'lore': True,
#    'pune': True},
#   'Negative'),
#  ({'got': True,
#    'back': True,
#    'astros': True,
#    'game': True,
#    'tired': True,
#    'could': True,
#    'possibly': True,
#    'happens': True,
#    'youve': True,
#    'hour': True},
#   'Negative'),
#  ({'happy': True, 'sore': True, 'wait': True, 'hot': True, 'shower': True},
#   'Positive'),
#  ({'got': True,
#    'realized': True,
#    'rain': True,
#    'last': True,
#    'night': True,
#    'bad': True,
#    'dream': True},
#   'Negative'),
#  ({'sammi': True,
#    'nice': True,
#    'weather': True,
#    'like': True,
#    'need': True,
#    'bouncy': True,
#    'castle': True},
#   'Positive'),
#  ({'there': True,
#    'pregnant': True,
#    'seagull': True,
#    'outside': True,
#    'window': True,
#    'still': True,
#    'sitting': True,
#    'egg': True,
#    'name': True,
#    'peggy': True},
#   'Positive'),
#  ({'saravananp': True,
#    'good': True,
#    'morning': True,
#    'glad': True,
#    'liked': True},
#   'Positive'),
#  ({'headache': True,
#    'day': True,
#    'today': True,
#    'amp': True,
#    'wished': True,
#    'daniel': True,
#    'happy': True,
#    'bday': True,
#    'tomorrow': True},
#   'Positive'),
#  ({'know': True, 'cook': True, 'dinner': True}, 'Negative'),
#  ({'live': True,
#    'vienam': True,
#    'tooo': True,
#    'bad': True,
#    'dont': True,
#    'understand': True,
#    'none': True,
#    'suckas': True},
#   'Negative'),
#  ({'teeeeeef': True,
#    'hear': True,
#    'ya': True,
#    'imagine': True,
#    'twitterless': True,
#    'know': True,
#    'answer': True},
#   'Negative'),
#  ({'go': True,
#    'pick': True,
#    'daughter': True,
#    'sleep': True,
#    'pm': True,
#    'uncomfortable': True,
#    'wanted': True,
#    'come': True,
#    'home': True,
#    'benadryl': True,
#    'kicked': True,
#    'long': True,
#    'ago': True,
#    'tired': True},
#   'Negative'),
#  ({'thinking': True,
#    'liberating': True,
#    'weed': True,
#    'junk': True,
#    'life': True},
#   'Positive'),
#  ({'headed': True, 'work': True, 'soon': True, 'hour': True, 'sleep': True},
#   'Negative'),
#  ({'mom': True,
#    'dog': True,
#    'keep': True,
#    'dry': True,
#    'cough': True,
#    'got': True,
#    'water': True,
#    'still': True,
#    'going': True},
#   'Negative'),
#  ({'sjcnkotb': True,
#    'everybody': True,
#    'send': True,
#    'dm': True,
#    'anybody': True,
#    'option': True,
#    'protected': True,
#    'cause': True,
#    'otherwise': True,
#    'get': True,
#    'hundred': True,
#    'day': True},
#   'Negative'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'cruk': True,
#    'mom': True,
#    'screamed': True,
#    'name': True,
#    'bathroom': True,
#    'opened': True,
#    'door': True,
#    'came': True,
#    'face': True,
#    'bubble': True},
#   'Positive'),
#  ({'enjoying': True,
#    'relaxed': True,
#    'sunday': True,
#    'afternoon': True,
#    'catching': True,
#    'lot': True,
#    'tv': True,
#    'show': True,
#    'lovely': True},
#   'Positive'),
#  ({'montelimart': True, 'parent': True, 'watching': True, 'movie': True},
#   'Negative'),
#  ({'dear': True, 'sun': True, 'please': True, 'come': True, 'back': True},
#   'Negative'),
#  ({'day': True,
#    'like': True,
#    'double': True,
#    'think': True,
#    'movin': True,
#    'fl': True,
#    'least': True,
#    'rain': True,
#    'chance': True,
#    'r': True,
#    'still': True,
#    'sunny': True,
#    'shit': True,
#    'fuckn': True,
#    'sux': True},
#   'Negative'),
#  ({'super': True,
#    'sad': True,
#    'rafa': True,
#    'nadal': True,
#    'withdrawal': True,
#    'fr': True,
#    'wimby': True,
#    'hope': True,
#    'recovers': True,
#    'soon': True},
#   'Negative'),
#  ({'tired': True, 'go': True, 'work': True, 'today': True}, 'Negative'),
#  ({'back': True,
#    'wine': True,
#    'blogger': True,
#    'conf': True,
#    'last': True,
#    'minute': True,
#    'sale': True,
#    'trip': True,
#    'see': True,
#    'guy': True,
#    'next': True,
#    'year': True,
#    'wbc': True},
#   'Negative'),
#  ({'must': True,
#    'stody': True,
#    'quot': True,
#    'kejsarn': True,
#    'av': True,
#    'portugallien': True,
#    'selma': True,
#    'lagerl': True,
#    'f': True,
#    'feel': True,
#    'lazy': True,
#    'today': True},
#   'Negative'),
#  ({'rye': True,
#    'happy': True,
#    'mother': True,
#    'day': True,
#    'mum': True,
#    'ily': True,
#    'mummy': True,
#    'lol': True},
#   'Positive'),
#  ({'beware': True,
#    'innocent': True,
#    'looking': True,
#    'coding': True,
#    'update': True,
#    'drag': True,
#    'middle': True,
#    'night': True},
#   'Negative'),
#  ({'final': True, 'next': True, 'week': True, 'nooooooooo': True}, 'Negative'),
#  ({'computer': True, 'apps': True, 'ally': True}, 'Positive'),
#  ({'watudoinsammie': True, 'know': True, 'sad': True}, 'Negative'),
#  ({'going': True, 'bed': True, 'niighty': True}, 'Positive'),
#  ({'mad': True,
#    'computer': True,
#    'giving': True,
#    'false': True,
#    'hope': True,
#    'stupid': True,
#    'die': True,
#    'charger': True,
#    'sight': True},
#   'Negative'),
#  ({'sherkro': True, 'see': True, 'yes': True}, 'Positive'),
#  ({'krnshrrr': True,
#    'kinda': True,
#    'like': True,
#    'almost': True,
#    'none': True,
#    'friend': True},
#   'Negative'),
#  ({'keen': True,
#    'use': True,
#    'coda': True,
#    'student': True,
#    'nzd': True,
#    'much': True,
#    'adsocialsync': True},
#   'Negative'),
#  ({'wow': True,
#    'think': True,
#    'actually': True,
#    'starting': True,
#    'get': True,
#    'hang': True,
#    'twitter': True,
#    'stuff': True,
#    'woo': True,
#    'hoo': True,
#    'ha': True},
#   'Positive'),
#  ({'nowhere': True, 'go': True, 'straight': True, 'home': True}, 'Negative'),
#  ({'need': True,
#    'breast': True,
#    'lol': True,
#    'http': True,
#    'mypict': True,
#    'ez': True},
#   'Negative'),
#  ({'found': True,
#    'nd': True,
#    'season': True,
#    'hero': True,
#    'k': True,
#    'mart': True,
#    'yesterday': True,
#    'allowed': True,
#    'get': True},
#   'Negative'),
#  ({'leonkay': True,
#    'hiya': True,
#    'r': True,
#    'u': True,
#    'quick': True,
#    'question': True,
#    'old': True,
#    'linehan': True,
#    'talkin': True,
#    'like': True,
#    'ur': True,
#    'well': True,
#    'last': True,
#    'nite': True,
#    'lol': True,
#    'p': True,
#    'amp': True,
#    'sammys': True,
#    'mood': True,
#    'mornin': True},
#   'Positive'),
#  ({'samjmoody': True,
#    'mother': True,
#    'day': True,
#    'uk': True,
#    'oh': True,
#    'well': True,
#    'happy': True,
#    'americna': True},
#   'Positive'),
#  ({'yessssss': True,
#    'spanish': True,
#    'class': True,
#    'anymore': True,
#    'classe': True,
#    'de': True,
#    'death': True,
#    'los': True,
#    'muertos': True,
#    'hehe': True,
#    'thats': True,
#    'left': True,
#    'history': True,
#    'chemistry': True,
#    'final': True,
#    'tomorrow': True},
#   'Negative'),
#  ({'wife': True, 'sick': True, 'summer': True, 'cold': True}, 'Negative'),
#  ({'oprah': True,
#    'thank': True,
#    'soo': True,
#    'much': True,
#    'featuring': True,
#    'invisible': True,
#    'child': True,
#    'show': True,
#    'friday': True,
#    'grateful': True},
#   'Positive'),
#  ({'basiacruz': True, 'dead': True, 'house': True}, 'Negative'),
#  ({'writing': True, 'oneshot': True}, 'Positive'),
#  ({'torra': True,
#    'k': True,
#    'blue': True,
#    'meany': True,
#    'love': True,
#    'use': True,
#    'nasal': True,
#    'spray': True,
#    'give': True,
#    'migraine': True,
#    'regular': True,
#    'anithist': True,
#    'work': True,
#    'grrr': True},
#   'Positive'),
#  ({'went': True,
#    'salsa': True,
#    'dancing': True,
#    'tonight': True,
#    'w': True,
#    'friend': True,
#    'much': True,
#    'fun': True,
#    'highly': True,
#    'recommend': True,
#    'however': True,
#    'smart': True,
#    'ur': True,
#    'sick': True,
#    'whole': True,
#    'body': True,
#    'ache': True},
#   'Negative'),
#  ({'kmeker': True,
#    'http': True,
#    'www': True,
#    'themusicninja': True,
#    'com': True,
#    'good': True,
#    'place': True,
#    'look': True,
#    'new': True,
#    'music': True},
#   'Positive'),
#  ({'yahooguy': True,
#    'thank': True,
#    'ff': True,
#    'luv': True,
#    'guy': True,
#    'super': True,
#    'customer': True,
#    'service': True},
#   'Positive'),
#  ({'another': True, 'day': True, 'first': True}, 'Positive'),
#  ...]

# %% [markdown]
# #NaiveBayes Classifier

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print(" Training Accuracy is:", round(classify.accuracy(classifier, train_data),2)*100)

print("Testing Accuracy is:", round(classify.accuracy(classifier, test_data),2)*100)

print(classifier.show_most_informative_features(10))
# Out:
#  Training Accuracy is: 86.0
# Testing Accuracy is: 77.0
# Most Informative Features
#                  fawcett = True           Negati : Positi =     60.4 : 1.0
#              squarespace = True           Negati : Positi =     57.9 : 1.0
#                   farrah = True           Negati : Positi =     45.1 : 1.0
#                     iran = True           Negati : Positi =     41.9 : 1.0
#                   booooo = True           Negati : Positi =     36.4 : 1.0
#               devastated = True           Negati : Positi =     31.0 : 1.0
#             followfriday = True           Positi : Negati =     29.9 : 1.0
#                   stuffy = True           Negati : Positi =     29.0 : 1.0
#                upsetting = True           Negati : Positi =     28.4 : 1.0
#               antibiotic = True           Negati : Positi =     27.7 : 1.0
# None

# %% [markdown]
# ### TFIDF for sentiment analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
vector = tfidf.fit_transform(data_cleaned['text'])
y = data_cleaned['Sentiment']

# %%
#splitting the data into train and test split with 33% test_size

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(vector,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=42,
                                                    stratify = y)

# %%
#Importing libraries and machine learning algorithms

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Printing the confusion matrix label for training  and testing accuracy along with the ACCURACY SCORE
# # MultinomialNB
# # LinearSVC
# # LogisticRegression

# %%
def metrics(y_train,y_train_pred,y_test,y_test_pred):
  print("training accuracy = ",round(accuracy_score(y_train,y_train_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred,normalize = 'all')
  print(classification_report(y_train,y_train_pred))
  plt.show()

  print("testing accuracy = ",round(accuracy_score(y_test,y_test_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_test,y_test_pred,normalize = 'all')
  print(classification_report(y_test,y_test_pred))
  plt.show()

# %% [markdown]
# ### Multinomial NB

# %%
NB = MultinomialNB()
NB.fit(X_train,y_train)
y_train_pred = NB.predict(X_train)
y_test_pred = NB.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  85.0
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85    166545
#            1       0.87      0.82      0.85    166546
#
#     accuracy                           0.85    333091
#    macro avg       0.85      0.85      0.85    333091
# weighted avg       0.85      0.85      0.85    333091
# testing accuracy =  76.0
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77     82031
#            1       0.78      0.73      0.75     82030
#
#     accuracy                           0.76    164061
#    macro avg       0.76      0.76      0.76    164061
# weighted avg       0.76      0.76      0.76    164061

# %% [markdown]
# ### Linear SVC

# %%
svc = LinearSVC()
svc.fit(X_train,y_train)
y_train_pred = svc.predict(X_train)
y_test_pred = svc.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  90.0
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90    166545
#            1       0.90      0.90      0.90    166546
#
#     accuracy                           0.90    333091
#    macro avg       0.90      0.90      0.90    333091
# weighted avg       0.90      0.90      0.90    333091
# testing accuracy =  77.0
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     82031
#            1       0.76      0.78      0.77     82030
#
#     accuracy                           0.77    164061
#    macro avg       0.77      0.77      0.77    164061
# weighted avg       0.77      0.77      0.77    164061

# %% [markdown]
# ### Logistic regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  82.0
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82    166545
#            1       0.81      0.84      0.83    166546
#
#     accuracy                           0.82    333091
#    macro avg       0.82      0.82      0.82    333091
# weighted avg       0.82      0.82      0.82    333091
# testing accuracy =  78.0
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     82031
#            1       0.76      0.80      0.78     82030
#
#     accuracy                           0.78    164061
#    macro avg       0.78      0.78      0.78    164061
# weighted avg       0.78      0.78      0.78    164061

# %% [markdown]
# ## Conclusion
#
# |Model|Training Accuracy|Testing Accuracy|
# |---|---|---|
# |Naive Bayes|86%|77%|
# |Multinomial NB| 85%|76%|
# |linear SVC|90%|77%|
# |Logistic|82%|78%|

# %% [markdown]
# # We see that Logistic regression model performs best with least overfitting as compared to other models and has better performance in testing dataset as well
